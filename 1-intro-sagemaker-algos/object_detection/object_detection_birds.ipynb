# %% [markdown]
# # Amazon SageMaker Object Detection for Bird Species
#
# 1. [Introduction](#Introduction)
# 2. [Setup](#Setup)
# 3. [Data Preparation](#Data-Preparation)
#   1. [Download and unpack the dataset](#Download-and-unpack-the-dataset)
#   2. [Understand the dataset](#Understand-the-dataset)
#   3. [Generate RecordIO files](#Generate-RecordIO-files)
# 4. [Train the model](#Train-the-model)
# 5. [Host the model](#Host-the-model)
# 6. [Test the model](#Test-the-model)
# 7. [Clean up](#Clean-up)
# 8. [Improve the model](#Improve-the-model)
# 9. [Final cleanup](#Final-cleanup)

# %% [markdown]
# ## Introduction
#
# Object detection is the process of identifying and localizing objects in an image. A typical object detection solution takes an image as input and provides a bounding box on the image where an object of interest is found.  It also identifies what type of object the box encapsulates.  To create such a solution, we need to acquire and process a traning dataset, create and setup a training job for the alorithm so that it can learn about the dataset. Finally, we can then host the trained model in an endpoint, to which we can supply images.
#
# This notebook is an end-to-end example showing how the Amazon SageMaker Object Detection algorithm can be used with a publicly available dataset of bird images. We demonstrate how to train and to host an object detection model based on the [Caltech Birds (CUB 200 2011)](http://www.vision.caltech.edu/visipedia/CUB-200-2011.html) dataset.  Amazon SageMaker's object detection algorithm uses the Single Shot multibox Detector ([SSD](https://arxiv.org/abs/1512.02325)) algorithm, and this notebook uses a [ResNet](https://arxiv.org/pdf/1603.05027.pdf) base network with that algorithm.
#
# ![Sample results detecting a pair of goldfinch on a feeder](./goldfinch_detections.png)
#
# We will also demonstrate how to construct a training dataset using the RecordIO format, as this is the format that the training job consumes.  This notebook is similar to the [Object Detection using the RecordIO format](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/introduction_to_amazon_algorithms/object_detection_pascalvoc_coco/object_detection_recordio_format.ipynb) notebook, with the following key differences:
#
# - We provide an example of how to translate bounding box specifications when providing images to SageMaker's algorithm. You will see code for generating the train.lst and val.lst files used to create [recordIO](https://mxnet.incubator.apache.org/architecture/note_data_loading.html) files.
# - We demonstrate how to improve an object detection model by adding training images that are flipped horizontally (mirror images).
# - We give you a notebook for experimenting with object detection challenges with an order of magnitude more classes (200 bird species, as opposed to the 20 categories used by [Pascal VOC](http://host.robots.ox.ac.uk/pascal/VOC/)).
# - We show how to chart the accuracy improvements that occur across the epochs of the training job.
#
# Note that Amazon SageMaker Object Detection also allows training with the image and JSON format, which is illustrated in the [image and JSON Notebook](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/introduction_to_amazon_algorithms/object_detection_pascalvoc_coco/object_detection_image_json_format.ipynb).

# %% [markdown]
# ## Setup
#
# Before preparing the data, there are some initial steps required for setup.

# %% [markdown]
# This notebook requires two additional Python packages:
# * **OpenCV** is required for gathering image sizes and flipping of images horizontally.
# * The **MXNet** runtime is required for using the im2rec tool.

# %%
import sys
# !{sys.executable} -m pip install opencv-python
# !{sys.executable} -m pip install mxnet
# Out:
# Requirement already satisfied: opencv-python in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (4.2.0.32)
# Requirement already satisfied: numpy>=1.11.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from opencv-python) (1.18.1)
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# Collecting mxnet
#   Downloading mxnet-1.7.0.post1-py2.py3-none-manylinux2014_x86_64.whl (55.0 MB)
#      |████████████████████████████████| 55.0 MB 70 kB/s  eta 0:00:01
# Requirement already satisfied: requests<3,>=2.20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from mxnet) (2.22.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from mxnet) (1.18.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2020.6.20)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.7.0.post1
# WARNING: You are using pip version 20.0.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# We need to identify the S3 bucket that you want to use for providing training and validation datasets.  It will also be used to store the tranied model artifacts. In this notebook, we use a custom bucket. You could alternatively use a default bucket for the session.  We use an object prefix to help organize the bucket content.

# %%
bucket = 'fab-sagemaker' # custom bucket name.
prefix = 'object-detection-birds'

# %% [markdown]
# To train the Object Detection algorithm on Amazon SageMaker, we need to setup and authenticate the use of AWS services. To begin with, we need an AWS account role with SageMaker access. Here we will use the execution role the current notebook instance was given when it was created.  This role has necessary permissions, including access to your data in S3.

# %%
import sagemaker
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
sess = sagemaker.Session()
# Out:
# arn:aws:iam::640463227255:role/service-role/AmazonSageMaker-ExecutionRole-20200822T102773

# %% [markdown]
# # Data Preparation
#
# The [Caltech Birds (CUB 200 2011)](http://www.vision.caltech.edu/visipedia/CUB-200-2011.html) dataset contains 11,788 images across 200 bird species (the original technical report can be found [here](http://www.vision.caltech.edu/visipedia/papers/CUB_200_2011.pdf)).  Each species comes with around 60 images, with a typical size of about 350 pixels by 500 pixels.  Bounding boxes are provided, as are annotations of bird parts.  A recommended train/test split is given, but image size data is not.
#
# ![](./cub_200_2011_snapshot.png)
#
# The dataset can be downloaded [here](http://www.vision.caltech.edu/visipedia/CUB-200-2011.html).
#
# ## Download and unpack the dataset
#
# Here we download the birds dataset from CalTech.

# %%
import os 
import urllib.request

def download(url):
    filename = url.split('/')[-1]
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)

# %%
# %%time
download ('https://s3.amazonaws.com/fast-ai-imageclas/CUB_200_2011.tgz')
# Out:
# CPU times: user 3.85 s, sys: 2.67 s, total: 6.53 s
# Wall time: 27.2 s

# %% [markdown]
# Now we unpack the dataset into its own directory structure.

# %%
# %%time
# Clean up prior version of the downloaded dataset if you are running this again
# !rm -rf CUB_200_2011  

# Unpack and then remove the downloaded compressed tar file
# !gunzip -c ./CUB_200_2011.tgz | tar xopf - 
# !rm CUB_200_2011.tgz
# Out:
# CPU times: user 132 ms, sys: 40.9 ms, total: 173 ms
# Wall time: 9.05 s

# %% [markdown]
# # Understand the dataset

# %% [markdown]
# ## Set some parameters for the rest of the notebook to use

# %% [markdown]
# Here we define a few parameters that help drive the rest of the notebook.  For example, `SAMPLE_ONLY` is defaulted to `True`. This will force the notebook to train on only a handful of species.  Setting to false will make the notebook work with the entire dataset of 200 bird species.  This makes the training a more difficult challenge, and you will need many more epochs to complete.
#
# The file parameters define names and locations of metadata files for the dataset.

# %%
import pandas as pd
import cv2
import boto3
import json

runtime = boto3.client(service_name='runtime.sagemaker')

import matplotlib.pyplot as plt
# %matplotlib inline

RANDOM_SPLIT = False
SAMPLE_ONLY  = True
FLIP         = False

# To speed up training and experimenting, you can use a small handful of species.
# To see the full list of the classes available, look at the content of CLASSES_FILE.
CLASSES = [17, 36, 47, 68, 73]

# Otherwise, you can use the full set of species
if (not SAMPLE_ONLY):
    CLASSES = []
    for c in range(200):
        CLASSES += [c + 1]

RESIZE_SIZE = 256

BASE_DIR   = 'CUB_200_2011/'
IMAGES_DIR = BASE_DIR + 'images/'

CLASSES_FILE = BASE_DIR + 'classes.txt'
BBOX_FILE    = BASE_DIR + 'bounding_boxes.txt'
IMAGE_FILE   = BASE_DIR + 'images.txt'
LABEL_FILE   = BASE_DIR + 'image_class_labels.txt'
SIZE_FILE    = BASE_DIR + 'sizes.txt'
SPLIT_FILE   = BASE_DIR + 'train_test_split.txt'

TRAIN_LST_FILE = 'birds_ssd_train.lst'
VAL_LST_FILE   = 'birds_ssd_val.lst'

if (SAMPLE_ONLY):
    TRAIN_LST_FILE = 'birds_ssd_sample_train.lst'
    VAL_LST_FILE   = 'birds_ssd_sample_val.lst'

TRAIN_RATIO     = 0.8
CLASS_COLS      = ['class_number','class_id']
IM2REC_SSD_COLS = ['header_cols', 'label_width', 'zero_based_id', 'xmin', 'ymin', 'xmax', 'ymax', 'image_file_name']

# %% [markdown]
# ## Explore the dataset images
#
# For each species, there are dozens of images of various shapes and sizes. By dividing the entire dataset into individual named (numbered) folders, the images are in effect labelled for supervised learning using image classification and object detection algorithms.
#
# The following function displays a grid of thumbnail images for all the image files for a given species.

# %%
def show_species(species_id):
    _im_list = !ls $IMAGES_DIR/$species_id

    NUM_COLS = 6
    IM_COUNT = len(_im_list)

    print('Species ' + species_id + ' has ' + str(IM_COUNT) + ' images.')
    
    NUM_ROWS = int(IM_COUNT / NUM_COLS)
    if ((IM_COUNT % NUM_COLS) > 0):
        NUM_ROWS += 1

    fig, axarr = plt.subplots(NUM_ROWS, NUM_COLS)
    fig.set_size_inches(8.0, 16.0, forward=True)

    curr_row = 0
    for curr_img in range(IM_COUNT):
        # fetch the url as a file type object, then read the image
        f = IMAGES_DIR + species_id + '/' + _im_list[curr_img]
        a = plt.imread(f)

        # find the column by taking the current index modulo 3
        col = curr_img % NUM_ROWS
        # plot on relevant subplot
        axarr[col, curr_row].imshow(a)
        if col == (NUM_ROWS - 1):
            # we have finished the current row, so increment row counter
            curr_row += 1

    fig.tight_layout()       
    plt.show()
        
    # Clean up
    plt.clf()
    plt.cla()
    plt.close()

# %% [markdown]
# Show the list of bird species or dataset classes.

# %%
classes_df = pd.read_csv(CLASSES_FILE, sep=' ', names=CLASS_COLS, header=None)
criteria = classes_df['class_number'].isin(CLASSES)
classes_df = classes_df[criteria]
print(classes_df.to_csv(columns=['class_id'], sep='\t', index=False, header=False))
# Out:
# 017.Cardinal
# 036.Northern_Flicker
# 047.American_Goldfinch
# 068.Ruby_throated_Hummingbird
# 073.Blue_Jay

# %% [markdown]
# Now for any given species, display thumbnail images of each of the images provided for training and testing.

# %%
show_species('017.Cardinal')
# Out:
# Species 017.Cardinal has 57 images.

# %% [markdown]
# # Generate RecordIO files

# %% [markdown]
# ## Step 1. Gather image sizes
#
# For this particular dataset, bounding box annotations are specified in absolute terms.  RecordIO format requires them to be defined in terms relative to the image size.  The following code visits each image, extracts the height and width, and saves this information into a file for subsequent use.  Some other publicly available datasets provide such a file for exactly this purpose.

# %%
# %%time
SIZE_COLS = ['idx','width','height']

def gen_image_size_file():
    print('Generating a file containing image sizes...')
    images_df = pd.read_csv(IMAGE_FILE, sep=' ',
                            names=['image_pretty_name', 'image_file_name'],
                            header=None)
    rows_list = []
    idx = 0
    for i in images_df['image_file_name']:
        # TODO: add progress bar
        idx += 1
        img = cv2.imread(IMAGES_DIR + i)
        dimensions = img.shape
        height = img.shape[0]
        width = img.shape[1]
        image_dict = {'idx': idx, 'width': width, 'height': height}
        rows_list.append(image_dict)

    sizes_df = pd.DataFrame(rows_list)
    print('Image sizes:\n' + str(sizes_df.head()))

    sizes_df[SIZE_COLS].to_csv(SIZE_FILE, sep=' ', index=False, header=None)

gen_image_size_file()
# Out:
# Generating a file containing image sizes...
# Image sizes:
#    idx  width  height
# 0    1    500     335
# 1    2    500     336
# 2    3    500     347
# 3    4    415     500
# 4    5    331     380
# CPU times: user 45.3 s, sys: 0 ns, total: 45.3 s
# Wall time: 45.4 s

# %% [markdown]
# ## Step 2. Generate list files for producing RecordIO files
#
# [RecordIO](https://mxnet.incubator.apache.org/architecture/note_data_loading.html) files can be created using the [im2rec tool](https://mxnet.incubator.apache.org/faq/recordio.html) (images to RecordIO), which takes as input a pair of list files, one for training images and the other for validation images.  Each list file has one row for each image.  For object detection, each row must contain bounding box data and a class label.
#
# For the CalTech birds dataset, we need to convert absolute bounding box dimensions to relative dimensions based on image size.  We also need to adjust class id's to be zero-based (instead of 1 to 200, they need to be 0 to 199).  This  dataset comes with recommended train/test split information ("is_training_image" flag).  This notebook is built flexibly to either leverage this suggestion, or to create a random train/test split with a specific train/test ratio.  The `RAMDOM_SPLIT` variable defined earlier controls whether or not the split happens randomly.

# %%
def split_to_train_test(df, label_column, train_frac=0.8):
    train_df, test_df = pd.DataFrame(), pd.DataFrame()
    labels = df[label_column].unique()
    for lbl in labels:
        lbl_df = df[df[label_column] == lbl]
        lbl_train_df = lbl_df.sample(frac=train_frac)
        lbl_test_df = lbl_df.drop(lbl_train_df.index)
        print('\n{}:\n---------\ntotal:{}\ntrain_df:{}\ntest_df:{}'.format(lbl, len(lbl_df), len(lbl_train_df), len(lbl_test_df)))
        train_df = train_df.append(lbl_train_df)
        test_df = test_df.append(lbl_test_df)
    return train_df, test_df

def gen_list_files():
    # use generated sizes file
    sizes_df = pd.read_csv(SIZE_FILE, sep=' ',
                names=['image_pretty_name', 'width', 'height'],
                header=None)
    bboxes_df = pd.read_csv(BBOX_FILE, sep=' ',
                names=['image_pretty_name', 'x_abs', 'y_abs', 'bbox_width', 'bbox_height'],
                header=None)
    split_df = pd.read_csv(SPLIT_FILE, sep=' ',
                            names=['image_pretty_name', 'is_training_image'],
                            header=None)
    print(IMAGE_FILE)
    images_df = pd.read_csv(IMAGE_FILE, sep=' ',
                            names=['image_pretty_name', 'image_file_name'],
                            header=None)
    print('num images total: ' + str(images_df.shape[0]))
    image_class_labels_df = pd.read_csv(LABEL_FILE, sep=' ',
                                names=['image_pretty_name', 'class_id'], header=None)

    # Merge the metadata into a single flat dataframe for easier processing
    full_df = pd.DataFrame(images_df)
    full_df.reset_index(inplace=True)
    full_df = pd.merge(full_df, image_class_labels_df, on='image_pretty_name')
    full_df = pd.merge(full_df, sizes_df, on='image_pretty_name')
    full_df = pd.merge(full_df, bboxes_df, on='image_pretty_name')
    full_df = pd.merge(full_df, split_df, on='image_pretty_name')
    full_df.sort_values(by=['index'], inplace=True)

    # Define the bounding boxes in the format required by SageMaker's built in Object Detection algorithm.
    # the xmin/ymin/xmax/ymax parameters are specified as ratios to the total image pixel size
    full_df['header_cols'] = 2  # one col for the number of header cols, one for the label width
    full_df['label_width'] = 5  # number of cols for each label: class, xmin, ymin, xmax, ymax
    full_df['xmin'] = full_df['x_abs'] / full_df['width']
    full_df['xmax'] = (full_df['x_abs'] + full_df['bbox_width']) / full_df['width']
    full_df['ymin'] = full_df['y_abs'] / full_df['height']
    full_df['ymax'] = (full_df['y_abs'] + full_df['bbox_height']) / full_df['height']

    # object detection class id's must be zero based. map from
    # class_id's given by CUB to zero-based (1 is 0, and 200 is 199).

    if SAMPLE_ONLY:
        # grab a small subset of species for testing
        criteria = full_df['class_id'].isin(CLASSES)
        full_df = full_df[criteria]

    unique_classes = full_df['class_id'].drop_duplicates()
    sorted_unique_classes = sorted(unique_classes)

    id_to_zero = {}
    i = 0.0
    for c in sorted_unique_classes:
        id_to_zero[c] = i
        i += 1.0

    full_df['zero_based_id'] = full_df['class_id'].map(id_to_zero)

    full_df.reset_index(inplace=True)

    # use 4 decimal places, as it seems to be required by the Object Detection algorithm
    pd.set_option("display.precision", 4)

    train_df = []
    val_df = []

    if (RANDOM_SPLIT):
        # split into training and validation sets
        train_df, val_df = split_to_train_test(full_df, 'class_id', TRAIN_RATIO)

        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep='\t',
                float_format='%.4f', header=None)
        val_df[IM2REC_SSD_COLS].to_csv(  VAL_LST_FILE, sep='\t',
                float_format='%.4f', header=None)
    else:
        train_df = full_df[(full_df.is_training_image == 1)]
        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep='\t',
                float_format='%.4f', header=None)

        val_df = full_df[(full_df.is_training_image == 0)]
        val_df[IM2REC_SSD_COLS].to_csv(  VAL_LST_FILE, sep='\t',
                float_format='%.4f', header=None)
        
    print('num train: ' + str(train_df.shape[0]))
    print('num val: ' + str(val_df.shape[0]))
    return train_df, val_df

# %%
train_df, val_df = gen_list_files()
# Out:
# CUB_200_2011/images.txt
# num images total: 11788
# num train: 150
# num val: 147

# %% [markdown]
# Here we take a look at a few records from the training list file to understand better what is being fed to the RecordIO files.
#
# The first column is the image number or index.  The second column indicates that the label is made up of 2 columns (column 2 and column 3).  The third column specifies the label width of a single object. In our case, the value 5 indicates each image has 5 numbers to describe its label information: the class index, and the 4 bounding box coordinates. If there are multiple objects within one image, all the label information should be listed in one line. Our dataset contains only one bounding box per image.
#
# The fourth column is the class label.  This identifies the bird species using a zero-based class id.  Columns 4 through 7 represent the bounding box for where the bird is found in this image.
#
# The classes should be labeled with successive numbers and start with 0. The bounding box coordinates are ratios of its top-left (xmin, ymin) and bottom-right (xmax, ymax) corner indices to the overall image size. Note that the top-left corner of the entire image is the origin (0, 0). The last column specifies the relative path of the image file within the images directory.

# %%
# !tail -3 $TRAIN_LST_FILE
# Out:
# 291	2	5	4.0000	0.4080	0.1527	0.9880	0.8728	073.Blue_Jay/Blue_Jay_0048_62433.jpg
# 294	2	5	4.0000	0.2500	0.1455	0.8260	0.8303	073.Blue_Jay/Blue_Jay_0086_63394.jpg
# 296	2	5	4.0000	0.2960	0.5400	0.8160	0.8460	073.Blue_Jay/Blue_Jay_0074_63487.jpg

# %% [markdown]
# ## Step 2. Convert data into RecordIO format
#
# Now we create im2rec databases (.rec files) for training and validation based on the list files created earlier.

# %%
# !python tools/im2rec.py --resize $RESIZE_SIZE --pack-label birds_ssd_sample $BASE_DIR/images/
# Out:
# Creating .rec file from /home/ec2-user/SageMaker/object_detection_birds/birds_ssd_sample_val.lst in /home/ec2-user/SageMaker/object_detection_birds
# multiprocessing not available, fall back to single threaded encoding
# time: 0.08909821510314941  count: 0
# Creating .rec file from /home/ec2-user/SageMaker/object_detection_birds/birds_ssd_sample_train.lst in /home/ec2-user/SageMaker/object_detection_birds
# multiprocessing not available, fall back to single threaded encoding
# time: 0.006628990173339844  count: 0

# %% [markdown]
# ## Step 3. Upload RecordIO files to S3
# Upload the training and validation data to the S3 bucket. We do this in multiple channels. Channels are simply directories in the bucket that differentiate the types of data provided to the algorithm. For the object detection algorithm, we call these directories `train` and `validation`.

# %%
# Upload the RecordIO files to train and validation channels
train_channel = prefix + '/train'
validation_channel = prefix + '/validation'

sess.upload_data(path='birds_ssd_sample_train.rec', bucket=bucket, key_prefix=train_channel)
sess.upload_data(path='birds_ssd_sample_val.rec', bucket=bucket, key_prefix=validation_channel)

s3_train_data = 's3://{}/{}'.format(bucket, train_channel)
s3_validation_data = 's3://{}/{}'.format(bucket, validation_channel)

# %% [markdown]
# # Train the model

# %% [markdown]
# Next we define an output location in S3, where the model artifacts will be placed on completion of the training. These artifacts are the output of the algorithm's traning job.  We also get the URI to the Amazon SageMaker Object Detection docker image.  This ensures the estimator uses the correct algorithm from the current region.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

training_image = get_image_uri(sess.boto_region_name, 'object-detection', repo_version='latest')
print (training_image)
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:latest

# %%
s3_output_location = 's3://{}/{}/output'.format(bucket, prefix)

# %%
od_model = sagemaker.estimator.Estimator(training_image,
                                         role, 
                                         train_instance_count=1, 
                                         train_instance_type='ml.p3.2xlarge',
                                         train_volume_size = 50,
                                         train_max_run = 360000,
                                         input_mode= 'File',
                                         output_path=s3_output_location,
                                         sagemaker_session=sess)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ## Define hyperparameters

# %% [markdown]
# The object detection algorithm at its core is the [Single-Shot Multi-Box detection algorithm (SSD)](https://arxiv.org/abs/1512.02325). This algorithm uses a `base_network`, which is typically a [VGG](https://arxiv.org/abs/1409.1556) or a [ResNet](https://arxiv.org/abs/1512.03385). The Amazon SageMaker object detection algorithm supports VGG-16 and ResNet-50. It also has a number of hyperparameters that help configure the training job. The next step in our training, is to setup these hyperparameters and data channels for training the model. See the SageMaker Object Detection [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection.html) for more details on its specific hyperparameters.
#
# One of the hyperparameters here for example is `epochs`. This defines how many passes of the dataset we iterate over and drives the training time of the algorithm. Based on our tests, we can achieve 70% accuracy on a sample mix of 5 species with 100 epochs.  When using the full 200 species, we can achieve 52% accuracy with 1,200 epochs.
#
# Note that Amazon SageMaker also provides [Automatic Model Tuning](https://docs.aws.amazon.com/sagemaker/latest/dg/automatic-model-tuning.html).  Automatic model tuning, also known as hyperparameter tuning, finds the best version of a model by running many training jobs on your dataset using the algorithm and ranges of hyperparameters that you specify. It then chooses the hyperparameter values that result in a model that performs the best, as measured by a metric that you choose.  When [tuning an Object Detection](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection-tuning.html) algorithm for example, the tuning job could find the best `validation:mAP` score by trying out various values for certain hyperparameters such as `mini_batch_size`, `weight_decay`, and `momentum`.

# %%
def set_hyperparameters(num_epochs, lr_steps):
    num_classes = classes_df.shape[0]
    num_training_samples = train_df.shape[0]
    print('num classes: {}, num training images: {}'.format(num_classes, num_training_samples))

    od_model.set_hyperparameters(base_network='resnet-50',
                                 use_pretrained_model=1,
                                 num_classes=num_classes,
                                 mini_batch_size=16,
                                 epochs=num_epochs,               
                                 learning_rate=0.001, 
                                 lr_scheduler_step=lr_steps,      
                                 lr_scheduler_factor=0.1,
                                 optimizer='sgd',
                                 momentum=0.9,
                                 weight_decay=0.0005,
                                 overlap_threshold=0.5,
                                 nms_threshold=0.45,
                                 image_shape=512,
                                 label_width=350,
                                 num_training_samples=num_training_samples)

# %%
set_hyperparameters(100, '33,67')
# Out:
# num classes: 5, num training images: 150

# %% [markdown]
# Now that the hyperparameters are setup, we define the data channels to be passed to the algorithm. To do this, we need to create the `sagemaker.session.s3_input` objects from our data channels. These objects are then put in a simple dictionary, which the algorithm consumes.  Note that you could add a third channel named `model` to perform incremental training (continue training from where you had left off with a prior model).

# %%
train_data = sagemaker.session.s3_input(s3_train_data, distribution='FullyReplicated', 
                        content_type='application/x-recordio', s3_data_type='S3Prefix')
validation_data = sagemaker.session.s3_input(s3_validation_data, distribution='FullyReplicated', 
                             content_type='application/x-recordio', s3_data_type='S3Prefix')
data_channels = {'train': train_data, 'validation': validation_data}
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %% [markdown]
# ## Submit training job

# %% [markdown]
# We have our `Estimator` object, we have set the hyperparameters for this object, and we have our data channels linked with the algorithm. The only remaining thing to do is to train the algorithm using the `fit` method. This will take more than 10 minutes in our example.
#
# The training process involves a few steps. First, the instances that we requested while creating the `Estimator` classes are provisioned and setup with the appropriate libraries. Then, the data from our channels are downloaded into the instance. Once this is done, the actual training begins. The provisioning and data downloading will take time, depending on the size of the data. Therefore it might be a few minutes before our training job logs show up in CloudWatch. The logs will also print out Mean Average Precision (mAP) on the validation data, among other losses, for every run of the dataset (once per epoch). This metric is a proxy for the accuracy of the model.
#
# Once the job has finished, a `Job complete` message will be printed. The trained model artifacts can be found in the S3 bucket that was setup as `output_path` in the estimator.

# %%
# %%time
od_model.fit(inputs=data_channels, logs=True)
# Out:
# 2020-10-08 14:48:55 Starting - Starting the training job...
# 2020-10-08 14:48:59 Starting - Launching requested ML instances......
# 2020-10-08 14:50:05 Starting - Preparing the instances for training......
# 2020-10-08 14:51:22 Downloading - Downloading input data
# 2020-10-08 14:51:22 Training - Downloading the training image......
# 2020-10-08 14:52:24 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# [10/08/2020 14:52:26 INFO 139755571353408] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [10/08/2020 14:52:26 INFO 139755571353408] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'100', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'label_width': u'350', u'lr_scheduler_step': u'33,67', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'150', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'5', u'lr_scheduler_factor': u'0.1'}
# [10/08/2020 14:52:26 INFO 139755571353408] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'100', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'33,67', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'150', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'5', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [10/08/2020 14:52:26 INFO 139755571353408] Using default worker.
# [10/08/2020 14:52:26 INFO 139755571353408] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/08/2020 14:52:26 INFO 139755571353408] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/08/2020 14:52:26 INFO 139755571353408] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/08/2020 14:52:26 INFO 139755571353408] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/08/2020 14:52:27 INFO 139755571353408] Checkpoint loading and saving are disabled.
# [10/08/2020 14:52:27 INFO 139755571353408] nvidia-smi took: 0.0504140853882 secs to identify 1 gpus
# [10/08/2020 14:52:27 INFO 139755571353408] Number of GPUs being used: 1
# [10/08/2020 14:52:27 WARNING 139755571353408] Training images are resized to image shape (3, 512, 512)
# [14:52:27] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, use 7 threads for decoding..
# [14:52:27] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, label padding width: 350
# [10/08/2020 14:52:28 WARNING 139755571353408] Validation images are resized to image shape (3, 512, 512)
# [14:52:28] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, use 7 threads for decoding..
# [14:52:28] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, label padding width: 350
# [10/08/2020 14:52:29 INFO 139755571353408] Number of GPUs being used: 1
# [10/08/2020 14:52:29 INFO 139755571353408] Using [gpu(0)] as training context.
# [10/08/2020 14:52:29 INFO 139755571353408] Number of GPUs being used: 1
# [10/08/2020 14:52:29 INFO 139755571353408] Create Store: device
# [10/08/2020 14:52:29 INFO 139755571353408] Using (gpu(0)) as training context.
# [10/08/2020 14:52:30 INFO 139755571353408] Start training from pretrained model 1.
# [14:52:30] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [14:52:30] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [10/08/2020 14:52:30 INFO 139755571353408] Loaded pretrained model parameters.
# [10/08/2020 14:52:40 INFO 139755571353408] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1602168760.436694, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1602168760.43661}
#
# [14:52:40] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/08/2020 14:52:48 INFO 139755571353408] #quality_metric: host=algo-1, epoch=0, batch=10 train cross_entropy <loss>=(2.150329153476166)
# [10/08/2020 14:52:48 INFO 139755571353408] #quality_metric: host=algo-1, epoch=0, batch=10 train smooth_l1 <loss>=(0.6920129733771856)
# [10/08/2020 14:52:48 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:52:48 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:52:50 INFO 139755571353408] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(1.473518186209784e-05)
# [10/08/2020 14:52:50 INFO 139755571353408] Updating the best model with validation-mAP=1.473518186209784e-05
# [10/08/2020 14:52:50 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:52:50 INFO 139755571353408] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1602168770.727542, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1602168760.436974}
#
# [10/08/2020 14:52:53 INFO 139755571353408] #quality_metric: host=algo-1, epoch=1, batch=9 train cross_entropy <loss>=(1.871683761904121)
# [10/08/2020 14:52:53 INFO 139755571353408] #quality_metric: host=algo-1, epoch=1, batch=9 train smooth_l1 <loss>=(0.6813358456560056)
# [10/08/2020 14:52:53 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:52:53 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:52:55 INFO 139755571353408] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(6.267193236405083e-06)
# [10/08/2020 14:52:55 INFO 139755571353408] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1602168775.257786, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1602168770.727753}
#
# [10/08/2020 14:52:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=2, batch=10 train cross_entropy <loss>=(1.8268706805038106)
# [10/08/2020 14:52:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=2, batch=10 train smooth_l1 <loss>=(0.6719410637780308)
# [10/08/2020 14:52:58 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:52:58 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:52:59 INFO 139755571353408] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(7.174115678438076e-05)
# [10/08/2020 14:52:59 INFO 139755571353408] Updating the best model with validation-mAP=7.174115678438076e-05
# [10/08/2020 14:53:00 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:00 INFO 139755571353408] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1602168780.119159, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1602168775.25798}
#
# [10/08/2020 14:53:02 INFO 139755571353408] #quality_metric: host=algo-1, epoch=3, batch=9 train cross_entropy <loss>=(1.812790391358687)
# [10/08/2020 14:53:02 INFO 139755571353408] #quality_metric: host=algo-1, epoch=3, batch=9 train smooth_l1 <loss>=(0.6621343385370284)
# [10/08/2020 14:53:02 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:02 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:04 INFO 139755571353408] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.0002832378030681584)
# [10/08/2020 14:53:04 INFO 139755571353408] Updating the best model with validation-mAP=0.0002832378030681584
# [10/08/2020 14:53:04 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:04 INFO 139755571353408] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1602168784.55846, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1602168780.119374}
#
# [10/08/2020 14:53:07 INFO 139755571353408] #quality_metric: host=algo-1, epoch=4, batch=9 train cross_entropy <loss>=(1.8037426076036818)
# [10/08/2020 14:53:07 INFO 139755571353408] #quality_metric: host=algo-1, epoch=4, batch=9 train smooth_l1 <loss>=(0.6569252135905813)
# [10/08/2020 14:53:07 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:07 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:09 INFO 139755571353408] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.00036955415312626)
# [10/08/2020 14:53:09 INFO 139755571353408] Updating the best model with validation-mAP=0.00036955415312626
# [10/08/2020 14:53:09 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:09 INFO 139755571353408] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1602168789.168866, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1602168784.558722}
#
# [10/08/2020 14:53:12 INFO 139755571353408] #quality_metric: host=algo-1, epoch=5, batch=10 train cross_entropy <loss>=(1.7871322426560747)
# [10/08/2020 14:53:12 INFO 139755571353408] #quality_metric: host=algo-1, epoch=5, batch=10 train smooth_l1 <loss>=(0.661591335690075)
# [10/08/2020 14:53:12 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:12 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:13 INFO 139755571353408] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.0005487237002793443)
# [10/08/2020 14:53:13 INFO 139755571353408] Updating the best model with validation-mAP=0.0005487237002793443
# [10/08/2020 14:53:14 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:14 INFO 139755571353408] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1602168794.072431, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1602168789.169181}
#
# [10/08/2020 14:53:16 INFO 139755571353408] #quality_metric: host=algo-1, epoch=6, batch=9 train cross_entropy <loss>=(1.770335328652384)
# [10/08/2020 14:53:16 INFO 139755571353408] #quality_metric: host=algo-1, epoch=6, batch=9 train smooth_l1 <loss>=(0.6461188886199889)
# [10/08/2020 14:53:16 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:16 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:18 INFO 139755571353408] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.0007152591303701316)
# [10/08/2020 14:53:18 INFO 139755571353408] Updating the best model with validation-mAP=0.0007152591303701316
# [10/08/2020 14:53:18 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:18 INFO 139755571353408] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1602168798.686987, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1602168794.072693}
#
# [10/08/2020 14:53:21 INFO 139755571353408] #quality_metric: host=algo-1, epoch=7, batch=9 train cross_entropy <loss>=(1.7524968400786194)
# [10/08/2020 14:53:21 INFO 139755571353408] #quality_metric: host=algo-1, epoch=7, batch=9 train smooth_l1 <loss>=(0.6524455718350309)
# [10/08/2020 14:53:21 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:21 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:22 INFO 139755571353408] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.0007563163671526165)
# [10/08/2020 14:53:22 INFO 139755571353408] Updating the best model with validation-mAP=0.0007563163671526165
# [10/08/2020 14:53:23 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:23 INFO 139755571353408] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1602168803.122494, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1602168798.687213}
#
# [10/08/2020 14:53:26 INFO 139755571353408] #quality_metric: host=algo-1, epoch=8, batch=10 train cross_entropy <loss>=(1.7490863511056611)
# [10/08/2020 14:53:26 INFO 139755571353408] #quality_metric: host=algo-1, epoch=8, batch=10 train smooth_l1 <loss>=(0.6379395651094841)
# [10/08/2020 14:53:26 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:26 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:28 INFO 139755571353408] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.0027629696208216967)
# [10/08/2020 14:53:28 INFO 139755571353408] Updating the best model with validation-mAP=0.0027629696208216967
# [10/08/2020 14:53:28 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:28 INFO 139755571353408] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1602168808.30218, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1602168803.122714}
#
# [10/08/2020 14:53:30 INFO 139755571353408] #quality_metric: host=algo-1, epoch=9, batch=9 train cross_entropy <loss>=(1.7347744003481227)
# [10/08/2020 14:53:30 INFO 139755571353408] #quality_metric: host=algo-1, epoch=9, batch=9 train smooth_l1 <loss>=(0.6516885834666881)
# [10/08/2020 14:53:30 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:30 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:32 INFO 139755571353408] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.0024224685697512064)
# [10/08/2020 14:53:32 INFO 139755571353408] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1602168812.910416, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1602168808.302477}
#
# [10/08/2020 14:53:35 INFO 139755571353408] #quality_metric: host=algo-1, epoch=10, batch=10 train cross_entropy <loss>=(1.7168251461452908)
# [10/08/2020 14:53:35 INFO 139755571353408] #quality_metric: host=algo-1, epoch=10, batch=10 train smooth_l1 <loss>=(0.6343274399086282)
# [10/08/2020 14:53:35 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:35 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:37 INFO 139755571353408] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.003144655716443071)
# [10/08/2020 14:53:37 INFO 139755571353408] Updating the best model with validation-mAP=0.003144655716443071
# [10/08/2020 14:53:37 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:37 INFO 139755571353408] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1602168817.74623, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1602168812.91064}
#
# [10/08/2020 14:53:40 INFO 139755571353408] #quality_metric: host=algo-1, epoch=11, batch=9 train cross_entropy <loss>=(1.7016023709372623)
# [10/08/2020 14:53:40 INFO 139755571353408] #quality_metric: host=algo-1, epoch=11, batch=9 train smooth_l1 <loss>=(0.6281440920568625)
# [10/08/2020 14:53:40 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:40 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:42 INFO 139755571353408] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.004601879416507214)
# [10/08/2020 14:53:42 INFO 139755571353408] Updating the best model with validation-mAP=0.004601879416507214
# [10/08/2020 14:53:42 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:42 INFO 139755571353408] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1602168822.372442, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1602168817.746722}
#
# [10/08/2020 14:53:44 INFO 139755571353408] #quality_metric: host=algo-1, epoch=12, batch=9 train cross_entropy <loss>=(1.6795835494995117)
# [10/08/2020 14:53:44 INFO 139755571353408] #quality_metric: host=algo-1, epoch=12, batch=9 train smooth_l1 <loss>=(0.6194062422192286)
# [10/08/2020 14:53:44 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:45 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:46 INFO 139755571353408] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.009062746780666741)
# [10/08/2020 14:53:46 INFO 139755571353408] Updating the best model with validation-mAP=0.009062746780666741
# [10/08/2020 14:53:46 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:46 INFO 139755571353408] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1602168826.954078, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1602168822.373201}
#
# [10/08/2020 14:53:49 INFO 139755571353408] #quality_metric: host=algo-1, epoch=13, batch=10 train cross_entropy <loss>=(1.659845459449848)
# [10/08/2020 14:53:49 INFO 139755571353408] #quality_metric: host=algo-1, epoch=13, batch=10 train smooth_l1 <loss>=(0.6420760468372967)
# [10/08/2020 14:53:49 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:49 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:51 INFO 139755571353408] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.013012221489812136)
# [10/08/2020 14:53:51 INFO 139755571353408] Updating the best model with validation-mAP=0.013012221489812136
# [10/08/2020 14:53:51 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:51 INFO 139755571353408] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1602168831.702504, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1602168826.954409}
#
# [10/08/2020 14:53:54 INFO 139755571353408] #quality_metric: host=algo-1, epoch=14, batch=9 train cross_entropy <loss>=(1.6309129124365482)
# [10/08/2020 14:53:54 INFO 139755571353408] #quality_metric: host=algo-1, epoch=14, batch=9 train smooth_l1 <loss>=(0.6352723523444935)
# [10/08/2020 14:53:54 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:54 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:53:55 INFO 139755571353408] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.01768011012289395)
# [10/08/2020 14:53:55 INFO 139755571353408] Updating the best model with validation-mAP=0.01768011012289395
# [10/08/2020 14:53:56 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:53:56 INFO 139755571353408] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1602168836.070499, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1602168831.702754}
#
# [10/08/2020 14:53:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=15, batch=9 train cross_entropy <loss>=(1.5879687206623074)
# [10/08/2020 14:53:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=15, batch=9 train smooth_l1 <loss>=(0.6168530941507784)
# [10/08/2020 14:53:58 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:53:58 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:00 INFO 139755571353408] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.02500690917234395)
# [10/08/2020 14:54:00 INFO 139755571353408] Updating the best model with validation-mAP=0.02500690917234395
# [10/08/2020 14:54:00 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:00 INFO 139755571353408] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1602168840.788881, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 15}, "StartTime": 1602168836.070982}
#
# [10/08/2020 14:54:03 INFO 139755571353408] #quality_metric: host=algo-1, epoch=16, batch=10 train cross_entropy <loss>=(1.5475483083013277)
# [10/08/2020 14:54:03 INFO 139755571353408] #quality_metric: host=algo-1, epoch=16, batch=10 train smooth_l1 <loss>=(0.612428946281547)
# [10/08/2020 14:54:03 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:04 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:05 INFO 139755571353408] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.021730769237701654)
# [10/08/2020 14:54:05 INFO 139755571353408] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1602168845.896958, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 16}, "StartTime": 1602168840.789245}
#
# [10/08/2020 14:54:08 INFO 139755571353408] #quality_metric: host=algo-1, epoch=17, batch=9 train cross_entropy <loss>=(1.498113540582782)
# [10/08/2020 14:54:08 INFO 139755571353408] #quality_metric: host=algo-1, epoch=17, batch=9 train smooth_l1 <loss>=(0.6203502005364697)
# [10/08/2020 14:54:08 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:08 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:10 INFO 139755571353408] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.021733186152118646)
# [10/08/2020 14:54:10 INFO 139755571353408] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1602168850.320473, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 17}, "StartTime": 1602168845.897153}
#
# [10/08/2020 14:54:13 INFO 139755571353408] #quality_metric: host=algo-1, epoch=18, batch=10 train cross_entropy <loss>=(1.4406728072905204)
# [10/08/2020 14:54:13 INFO 139755571353408] #quality_metric: host=algo-1, epoch=18, batch=10 train smooth_l1 <loss>=(0.593739622795366)
# [10/08/2020 14:54:13 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:13 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:14 INFO 139755571353408] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.025847726237432783)
# [10/08/2020 14:54:14 INFO 139755571353408] Updating the best model with validation-mAP=0.025847726237432783
# [10/08/2020 14:54:15 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:15 INFO 139755571353408] #progress_metric: host=algo-1, completed 19 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1602168855.120149, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 18}, "StartTime": 1602168850.32068}
#
# [10/08/2020 14:54:17 INFO 139755571353408] #quality_metric: host=algo-1, epoch=19, batch=9 train cross_entropy <loss>=(1.394440128970048)
# [10/08/2020 14:54:17 INFO 139755571353408] #quality_metric: host=algo-1, epoch=19, batch=9 train smooth_l1 <loss>=(0.6080148681201072)
# [10/08/2020 14:54:17 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:17 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:19 INFO 139755571353408] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.04303240729052972)
# [10/08/2020 14:54:19 INFO 139755571353408] Updating the best model with validation-mAP=0.04303240729052972
# [10/08/2020 14:54:19 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:19 INFO 139755571353408] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 20, "sum": 20.0, "min": 20}}, "EndTime": 1602168859.520201, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 19}, "StartTime": 1602168855.12037}
#
# [10/08/2020 14:54:22 INFO 139755571353408] #quality_metric: host=algo-1, epoch=20, batch=9 train cross_entropy <loss>=(1.3500934142444867)
# [10/08/2020 14:54:22 INFO 139755571353408] #quality_metric: host=algo-1, epoch=20, batch=9 train smooth_l1 <loss>=(0.6082360370581602)
# [10/08/2020 14:54:22 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:22 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:24 INFO 139755571353408] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.047100740969462505)
# [10/08/2020 14:54:24 INFO 139755571353408] Updating the best model with validation-mAP=0.047100740969462505
# [10/08/2020 14:54:24 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:24 INFO 139755571353408] #progress_metric: host=algo-1, completed 21 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 21, "sum": 21.0, "min": 21}}, "EndTime": 1602168864.35934, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 20}, "StartTime": 1602168859.523432}
#
# [10/08/2020 14:54:27 INFO 139755571353408] #quality_metric: host=algo-1, epoch=21, batch=10 train cross_entropy <loss>=(1.305450353729591)
# [10/08/2020 14:54:27 INFO 139755571353408] #quality_metric: host=algo-1, epoch=21, batch=10 train smooth_l1 <loss>=(0.5842180895001701)
# [10/08/2020 14:54:27 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:27 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:28 INFO 139755571353408] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.04589497162818133)
# [10/08/2020 14:54:28 INFO 139755571353408] #progress_metric: host=algo-1, completed 22 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 22, "sum": 22.0, "min": 22}}, "EndTime": 1602168868.947092, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 21}, "StartTime": 1602168864.359635}
#
# [10/08/2020 14:54:31 INFO 139755571353408] #quality_metric: host=algo-1, epoch=22, batch=9 train cross_entropy <loss>=(1.2680635012401098)
# [10/08/2020 14:54:31 INFO 139755571353408] #quality_metric: host=algo-1, epoch=22, batch=9 train smooth_l1 <loss>=(0.6064549933705877)
# [10/08/2020 14:54:31 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:31 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:33 INFO 139755571353408] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(0.05598225706129811)
# [10/08/2020 14:54:33 INFO 139755571353408] Updating the best model with validation-mAP=0.05598225706129811
# [10/08/2020 14:54:33 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:33 INFO 139755571353408] #progress_metric: host=algo-1, completed 23 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 23, "sum": 23.0, "min": 23}}, "EndTime": 1602168873.496145, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 22}, "StartTime": 1602168868.947305}
#
# [10/08/2020 14:54:35 INFO 139755571353408] #quality_metric: host=algo-1, epoch=23, batch=9 train cross_entropy <loss>=(1.2362711347382644)
# [10/08/2020 14:54:35 INFO 139755571353408] #quality_metric: host=algo-1, epoch=23, batch=9 train smooth_l1 <loss>=(0.5699227966111282)
# [10/08/2020 14:54:35 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:36 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:37 INFO 139755571353408] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.0707058792345201)
# [10/08/2020 14:54:37 INFO 139755571353408] Updating the best model with validation-mAP=0.0707058792345201
# [10/08/2020 14:54:37 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:37 INFO 139755571353408] #progress_metric: host=algo-1, completed 24 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 24, "sum": 24.0, "min": 24}}, "EndTime": 1602168877.969305, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 23}, "StartTime": 1602168873.49636}
#
# [10/08/2020 14:54:41 INFO 139755571353408] #quality_metric: host=algo-1, epoch=24, batch=10 train cross_entropy <loss>=(1.20500172390027)
# [10/08/2020 14:54:41 INFO 139755571353408] #quality_metric: host=algo-1, epoch=24, batch=10 train smooth_l1 <loss>=(0.5619776472170255)
# [10/08/2020 14:54:41 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:41 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:43 INFO 139755571353408] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.0858795237648493)
# [10/08/2020 14:54:43 INFO 139755571353408] Updating the best model with validation-mAP=0.0858795237648493
# [10/08/2020 14:54:43 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:54:43 INFO 139755571353408] #progress_metric: host=algo-1, completed 25 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 25, "sum": 25.0, "min": 25}}, "EndTime": 1602168883.236477, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 24}, "StartTime": 1602168877.969653}
#
# [10/08/2020 14:54:45 INFO 139755571353408] #quality_metric: host=algo-1, epoch=25, batch=9 train cross_entropy <loss>=(1.1559724338719102)
# [10/08/2020 14:54:45 INFO 139755571353408] #quality_metric: host=algo-1, epoch=25, batch=9 train smooth_l1 <loss>=(0.5808017292960745)
# [10/08/2020 14:54:45 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:45 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:47 INFO 139755571353408] #quality_metric: host=algo-1, epoch=25, validation mAP <score>=(0.07760361111786826)
# [10/08/2020 14:54:47 INFO 139755571353408] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 26, "sum": 26.0, "min": 26}}, "EndTime": 1602168887.716974, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 25}, "StartTime": 1602168883.236682}
#
# [10/08/2020 14:54:50 INFO 139755571353408] #quality_metric: host=algo-1, epoch=26, batch=10 train cross_entropy <loss>=(1.137551435452063)
# [10/08/2020 14:54:50 INFO 139755571353408] #quality_metric: host=algo-1, epoch=26, batch=10 train smooth_l1 <loss>=(0.565439672377503)
# [10/08/2020 14:54:50 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:54:50 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:54:52 INFO 139755571353408] #quality_metric: host=algo-1, epoch=26, validation mAP <score>=(0.09174692409455884)
# [10/08/2020 14:54:52 INFO 139755571353408] Updating the best model with validation-mAP=0.09174692409455884
# [10/08/2020 14:54:52 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# ...
#
# [10/08/2020 14:59:41 INFO 139755571353408] #quality_metric: host=algo-1, epoch=90, batch=10 train cross_entropy <loss>=(0.7989586296431516)
# [10/08/2020 14:59:41 INFO 139755571353408] #quality_metric: host=algo-1, epoch=90, batch=10 train smooth_l1 <loss>=(0.3892978983187894)
# [10/08/2020 14:59:41 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:59:41 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:59:42 INFO 139755571353408] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.5702947467253471)
# [10/08/2020 14:59:42 INFO 139755571353408] #progress_metric: host=algo-1, completed 91 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 91, "sum": 91.0, "min": 91}}, "EndTime": 1602169182.995681, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 90}, "StartTime": 1602169178.359493}
#
# [10/08/2020 14:59:45 INFO 139755571353408] #quality_metric: host=algo-1, epoch=91, batch=9 train cross_entropy <loss>=(0.7740917717058634)
# [10/08/2020 14:59:45 INFO 139755571353408] #quality_metric: host=algo-1, epoch=91, batch=9 train smooth_l1 <loss>=(0.34827439219681255)
# [10/08/2020 14:59:45 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:59:45 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:59:47 INFO 139755571353408] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.6281629135804291)
# [10/08/2020 14:59:47 INFO 139755571353408] #progress_metric: host=algo-1, completed 92 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 92, "sum": 92.0, "min": 92}}, "EndTime": 1602169187.251775, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 91}, "StartTime": 1602169182.995885}
#
# [10/08/2020 14:59:49 INFO 139755571353408] #quality_metric: host=algo-1, epoch=92, batch=9 train cross_entropy <loss>=(0.8129709397967604)
# [10/08/2020 14:59:49 INFO 139755571353408] #quality_metric: host=algo-1, epoch=92, batch=9 train smooth_l1 <loss>=(0.37631024078673303)
# [10/08/2020 14:59:49 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:59:49 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:59:51 INFO 139755571353408] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.6877871811489334)
# [10/08/2020 14:59:51 INFO 139755571353408] Updating the best model with validation-mAP=0.6877871811489334
# [10/08/2020 14:59:51 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 14:59:51 INFO 139755571353408] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 93, "sum": 93.0, "min": 93}}, "EndTime": 1602169191.549917, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 92}, "StartTime": 1602169187.251995}
#
# [10/08/2020 14:59:54 INFO 139755571353408] #quality_metric: host=algo-1, epoch=93, batch=10 train cross_entropy <loss>=(0.7999216667146284)
# [10/08/2020 14:59:54 INFO 139755571353408] #quality_metric: host=algo-1, epoch=93, batch=10 train smooth_l1 <loss>=(0.36502926975148714)
# [10/08/2020 14:59:54 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:59:54 INFO 139755571353408] Updated the metrics
# [10/08/2020 14:59:56 INFO 139755571353408] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.6474391634820379)
# [10/08/2020 14:59:56 INFO 139755571353408] #progress_metric: host=algo-1, completed 94 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 94, "sum": 94.0, "min": 94}}, "EndTime": 1602169196.123685, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 93}, "StartTime": 1602169191.550222}
#
# [10/08/2020 14:59:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=94, batch=9 train cross_entropy <loss>=(0.7753909879287988)
# [10/08/2020 14:59:58 INFO 139755571353408] #quality_metric: host=algo-1, epoch=94, batch=9 train smooth_l1 <loss>=(0.3726519374590995)
# [10/08/2020 14:59:58 INFO 139755571353408] Round of batches complete
# [10/08/2020 14:59:58 INFO 139755571353408] Updated the metrics
# [10/08/2020 15:00:00 INFO 139755571353408] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.6261876787065269)
# [10/08/2020 15:00:00 INFO 139755571353408] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 95, "sum": 95.0, "min": 95}}, "EndTime": 1602169200.278144, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 94}, "StartTime": 1602169196.131919}
#
# [10/08/2020 15:00:02 INFO 139755571353408] #quality_metric: host=algo-1, epoch=95, batch=9 train cross_entropy <loss>=(0.7625416423176433)
# [10/08/2020 15:00:02 INFO 139755571353408] #quality_metric: host=algo-1, epoch=95, batch=9 train smooth_l1 <loss>=(0.36880692092331496)
# [10/08/2020 15:00:02 INFO 139755571353408] Round of batches complete
# [10/08/2020 15:00:02 INFO 139755571353408] Updated the metrics
# [10/08/2020 15:00:04 INFO 139755571353408] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.6800445176430715)
# [10/08/2020 15:00:04 INFO 139755571353408] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1602169204.678193, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 95}, "StartTime": 1602169200.278422}
#
# [10/08/2020 15:00:07 INFO 139755571353408] #quality_metric: host=algo-1, epoch=96, batch=10 train cross_entropy <loss>=(0.7622996145967694)
# [10/08/2020 15:00:07 INFO 139755571353408] #quality_metric: host=algo-1, epoch=96, batch=10 train smooth_l1 <loss>=(0.36429412011581336)
# [10/08/2020 15:00:07 INFO 139755571353408] Round of batches complete
# [10/08/2020 15:00:07 INFO 139755571353408] Updated the metrics
# [10/08/2020 15:00:09 INFO 139755571353408] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.701592017993257)
# [10/08/2020 15:00:09 INFO 139755571353408] Updating the best model with validation-mAP=0.701592017993257
# [10/08/2020 15:00:09 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 15:00:09 INFO 139755571353408] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1602169209.832205, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 96}, "StartTime": 1602169204.678343}
#
# [10/08/2020 15:00:12 INFO 139755571353408] #quality_metric: host=algo-1, epoch=97, batch=9 train cross_entropy <loss>=(0.7712481728494803)
# [10/08/2020 15:00:12 INFO 139755571353408] #quality_metric: host=algo-1, epoch=97, batch=9 train smooth_l1 <loss>=(0.35031119185978415)
# [10/08/2020 15:00:12 INFO 139755571353408] Round of batches complete
# [10/08/2020 15:00:12 INFO 139755571353408] Updated the metrics
# [10/08/2020 15:00:14 INFO 139755571353408] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.682082530943273)
# [10/08/2020 15:00:14 INFO 139755571353408] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1602169214.168933, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 97}, "StartTime": 1602169209.832471}
#
# [10/08/2020 15:00:16 INFO 139755571353408] #quality_metric: host=algo-1, epoch=98, batch=10 train cross_entropy <loss>=(0.7751815323534423)
# [10/08/2020 15:00:16 INFO 139755571353408] #quality_metric: host=algo-1, epoch=98, batch=10 train smooth_l1 <loss>=(0.3740490990329191)
# [10/08/2020 15:00:16 INFO 139755571353408] Round of batches complete
# [10/08/2020 15:00:17 INFO 139755571353408] Updated the metrics
#
# 2020-10-08 15:00:27 Uploading - Uploading generated training model[10/08/2020 15:00:18 INFO 139755571353408] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.7023582146104006)
# [10/08/2020 15:00:18 INFO 139755571353408] Updating the best model with validation-mAP=0.7023582146104006
# [10/08/2020 15:00:18 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 15:00:18 INFO 139755571353408] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1602169218.906998, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 98}, "StartTime": 1602169214.169181}
#
# [10/08/2020 15:00:21 INFO 139755571353408] #quality_metric: host=algo-1, epoch=99, batch=9 train cross_entropy <loss>=(0.7643897162543403)
# [10/08/2020 15:00:21 INFO 139755571353408] #quality_metric: host=algo-1, epoch=99, batch=9 train smooth_l1 <loss>=(0.37032679603213353)
# [10/08/2020 15:00:21 INFO 139755571353408] Round of batches complete
# [10/08/2020 15:00:21 INFO 139755571353408] Updated the metrics
# [10/08/2020 15:00:23 INFO 139755571353408] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.6495656370030303)
# [10/08/2020 15:00:23 INFO 139755571353408] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1602169223.145424, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 99}, "StartTime": 1602169218.907271}
#
# [10/08/2020 15:00:23 WARNING 139755571353408] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/08/2020 15:00:23 INFO 139755571353408] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 15:00:23 INFO 139755571353408] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "totaltime": {"count": 1, "max": 476603.77311706543, "sum": 476603.77311706543, "min": 476603.77311706543}, "setuptime": {"count": 1, "max": 9.398221969604492, "sum": 9.398221969604492, "min": 9.398221969604492}}, "EndTime": 1602169223.51143, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1602168747.019891}
#
#
# 2020-10-08 15:00:44 Completed - Training job completed
# Training seconds: 579
# Billable seconds: 579
# CPU times: user 1.88 s, sys: 0 ns, total: 1.88 s
# Wall time: 12min 18s

# %% [markdown]
# Now that the training job is complete, you can also see the job listed in the `Training jobs` section of your SageMaker console.  Note that the job name is uniquely identified by the name of the algorithm concatenated with the date and time stamp.  You can click on the job to see the details including the hyperparameters, the data channel definitions, and the full path to the resulting model artifacts.  You could even clone the job from the console, and tweak some of the parameters to generate a new training job.

# %% [markdown]
# Without having to go to the CloudWatch console, you can see how the job progressed in terms of the key object detection algorithm metric, mean average precision (mAP).  This function below prepares a simple chart of that metric against the epochs.

# %%
import boto3
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
# %matplotlib inline

client = boto3.client('logs')
BASE_LOG_NAME = '/aws/sagemaker/TrainingJobs'

def plot_object_detection_log(model, title):
    logs = client.describe_log_streams(logGroupName=BASE_LOG_NAME, logStreamNamePrefix=model._current_job_name)
    cw_log = client.get_log_events(logGroupName=BASE_LOG_NAME, logStreamName=logs['logStreams'][0]['logStreamName'])

    mAP_accs=[]
    for e in cw_log['events']:
        msg = e['message']
        if 'validation mAP <score>=' in msg:
            num_start = msg.find('(')
            num_end = msg.find(')')
            mAP = msg[num_start+1:num_end]
            mAP_accs.append(float(mAP))

    print(title)
    print('Maximum mAP: %f ' % max(mAP_accs))

    fig, ax = plt.subplots()
    plt.xlabel('Epochs')
    plt.ylabel('Mean Avg Precision (mAP)')
    val_plot,   = ax.plot(range(len(mAP_accs)),   mAP_accs,   label='mAP')
    plt.legend(handles=[val_plot])
    ax.yaxis.set_ticks(np.arange(0.0, 1.05, 0.1))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter('%0.2f'))
    plt.show()

# %%
plot_object_detection_log(od_model, 'mAP tracking for job: ' + od_model._current_job_name)
# Out:
# mAP tracking for job: object-detection-2020-10-08-14-48-55-335
# Maximum mAP: 0.702358

# %% [markdown]
# # Host the model

# %% [markdown]
# Once the training is done, we can deploy the trained model as an Amazon SageMaker real-time hosted endpoint. This lets us make predictions (or inferences) from the model. Note that we don't have to host using the same type of instance that we used to train. Training is a prolonged and compute heavy job with different compute and memory requirements that hosting typically does not. In our case we chose the `ml.p3.2xlarge` instance to train, but we choose to host the model on the less expensive cpu instance, `ml.m4.xlarge`. The endpoint deployment takes several minutes, and can be accomplished with a single line of code calling the `deploy` method.
#
# Note that some use cases require large sets of inferences on a predefined body of images.  In those cases, you do not need to make the inferences in real time.  Instead, you could use SageMaker's [batch transform jobs](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-batch.html).

# %%
# %%time
object_detector = od_model.deploy(initial_instance_count = 1,
                                 instance_type = 'ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# ----------------------!CPU times: user 381 ms, sys: 14.1 ms, total: 395 ms
# Wall time: 11min 5s

# %% [markdown]
# # Test the model

# %% [markdown]
# Now that the trained model is deployed at an endpoint that is up-and-running, we can use this endpoint for inference.  The results of a call to the inference endpoint are in a format that is similar to the .lst format, with the addition of a confidence score for each detected object. The format of the output can be represented as `[class_index, confidence_score, xmin, ymin, xmax, ymax]`. Typically, we don't visualize low-confidence predictions.
#
# We have provided a script to easily visualize the detection outputs. You can visulize the high-confidence preditions with bounding box by filtering out low-confidence detections using the script below:

# %%
def visualize_detection(img_file, dets, classes=[], thresh=0.6):
        """
        visualize detections in one image
        Parameters:
        ----------
        img : numpy.array
            image, in bgr format
        dets : numpy.array
            ssd detections, numpy.array([[id, score, x1, y1, x2, y2]...])
            each row is one object
        classes : tuple or list of str
            class names
        thresh : float
            score threshold
        """
        import random
        import matplotlib.pyplot as plt
        import matplotlib.image as mpimg

        img = mpimg.imread(img_file)
        plt.imshow(img)
        height = img.shape[0]
        width  = img.shape[1]
        colors = dict()
        num_detections = 0
        for det in dets:
            (klass, score, x0, y0, x1, y1) = det
            if score < thresh:
                continue
            num_detections += 1
            cls_id = int(klass)
            if cls_id not in colors:
                colors[cls_id] = (random.random(), random.random(), random.random())
            xmin = int(x0 * width)
            ymin = int(y0 * height)
            xmax = int(x1 * width)
            ymax = int(y1 * height)
            rect = plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin, fill=False,
                                 edgecolor=colors[cls_id], linewidth=3.5)
            plt.gca().add_patch(rect)
            class_name = str(cls_id)
            if classes and len(classes) > cls_id:
                class_name = classes[cls_id]
            print('{},{}'.format(class_name,score))
            plt.gca().text(xmin, ymin - 2,
                            '{:s} {:.3f}'.format(class_name, score),
                            bbox=dict(facecolor=colors[cls_id], alpha=0.5),
                                    fontsize=12, color='white')

        print('Number of detections: ' + str(num_detections))
        plt.show()

# %% [markdown]
# Now we use our endpoint to try to detect objects within an image. Since the image is a jpeg, we use the appropriate content_type to run the prediction. The endpoint returns a JSON object that we can simply load and peek into. We have packaged the prediction code into a function to make it easier to test other images.  Note that we are defaulting the confidence threshold to 30% in our example, as a couple of the birds in our sample images were not being detected as clearly.  Defining an appropriate threshold is entirely dependent on your use case.

# %%
OBJECT_CATEGORIES = classes_df['class_id'].values.tolist()

def show_bird_prediction(filename, ep, thresh=0.40):
    b = ''
    with open(filename, 'rb') as image:
        f = image.read()
        b = bytearray(f)
    endpoint_response = runtime.invoke_endpoint(EndpointName=ep,
                                           ContentType='image/jpeg',
                                           Body=b)
    results = endpoint_response['Body'].read()
    detections = json.loads(results)
    visualize_detection(filename, detections['prediction'], OBJECT_CATEGORIES, thresh)

# %% [markdown]
# Here we download images that the algorithm has not yet seen.

# %%
# !wget -q -O multi-goldfinch-1.jpg https://t3.ftcdn.net/jpg/01/44/64/36/500_F_144643697_GJRUBtGc55KYSMpyg1Kucb9yJzvMQooW.jpg
# !wget -q -O northern-flicker-1.jpg https://upload.wikimedia.org/wikipedia/commons/5/5c/Northern_Flicker_%28Red-shafted%29.jpg
# !wget -q -O northern-cardinal-1.jpg https://cdn.pixabay.com/photo/2013/03/19/04/42/bird-94957_960_720.jpg
# !wget -q -O blue-jay-1.jpg https://cdn12.picryl.com/photo/2016/12/31/blue-jay-bird-feather-animals-b8ee04-1024.jpg
# !wget -q -O hummingbird-1.jpg http://res.freestockphotos.biz/pictures/17/17875-hummingbird-close-up-pv.jpg

# %%
def test_model():
    show_bird_prediction('hummingbird-1.jpg', object_detector.endpoint)
    show_bird_prediction('blue-jay-1.jpg', object_detector.endpoint)
    show_bird_prediction('multi-goldfinch-1.jpg', object_detector.endpoint)
    show_bird_prediction('northern-flicker-1.jpg', object_detector.endpoint)
    show_bird_prediction('northern-cardinal-1.jpg', object_detector.endpoint)

test_model()
# Out:
# 068.Ruby_throated_Hummingbird,0.46823108196258545
# Number of detections: 1
# Number of detections: 0
# 047.American_Goldfinch,0.47581812739372253
# 047.American_Goldfinch,0.4687120020389557
# Number of detections: 2
# 036.Northern_Flicker,0.8021687865257263
# Number of detections: 1
# 017.Cardinal,0.5840467214584351
# Number of detections: 1

# %% [markdown]
# # Clean up
# Here we delete the SageMaker endpoint, as we will no longer be performing any inferences.  This is an important step, as your account is billed for the amount of time an endpoint is running, even when it is idle.

# %%
sagemaker.Session().delete_endpoint(object_detector.endpoint)

# %% [markdown]
# # Improve the model

# %% [markdown]
# ## Define Function to Flip the Images Horizontally (on the X Axis)

# %%
from PIL import Image

def flip_images():
    print('Flipping images...')
    
    SIZE_COLS  = ['idx','width','height']
    IMAGE_COLS = ['image_pretty_name','image_file_name']
    LABEL_COLS = ['image_pretty_name','class_id']
    BBOX_COLS  = ['image_pretty_name', 'x_abs', 'y_abs', 'bbox_width', 'bbox_height']
    SPLIT_COLS = ['image_pretty_name', 'is_training_image']

    images_df = pd.read_csv(BASE_DIR + 'images.txt',
                            sep=' ', names=IMAGE_COLS, header=None)
    image_class_labels_df = pd.read_csv(BASE_DIR + 'image_class_labels.txt',
                            sep=' ', names=LABEL_COLS, header=None)
    bboxes_df = pd.read_csv(BASE_DIR + 'bounding_boxes.txt',
                            sep=' ', names=BBOX_COLS, header=None)
    split_df = pd.read_csv(BASE_DIR + 'train_test_split.txt',
                            sep=' ', names=SPLIT_COLS, header=None)

    NUM_ORIGINAL_IMAGES = images_df.shape[0]

    rows_list        = []
    bbox_rows_list   = []
    size_rows_list   = []
    label_rows_list  = []
    split_rows_list  = []

    idx = 0

    full_df = images_df.copy()
    full_df.reset_index(inplace=True)
    full_df = pd.merge(full_df, image_class_labels_df, on='image_pretty_name')
    full_df = pd.merge(full_df, bboxes_df, on='image_pretty_name')
    full_df = pd.merge(full_df, split_df, on='image_pretty_name')
    full_df.sort_values(by=['index'], inplace=True)

    if SAMPLE_ONLY:
        # grab a small subset of species for testing
        criteria = full_df['class_id'].isin(CLASSES)
        full_df = full_df[criteria]

    for rel_image_fn in full_df['image_file_name']:
        idx += 1
        full_img_content = full_df[(full_df.image_file_name == rel_image_fn)]

        class_id = full_img_content.iloc[0].class_id

        img = Image.open(IMAGES_DIR + rel_image_fn)

        width, height = img.size

        new_idx = idx + NUM_ORIGINAL_IMAGES

        flip_core_file_name = rel_image_fn[:-4] + '_flip.jpg'
        flip_full_file_name = IMAGES_DIR + flip_core_file_name

        img_flip = img.transpose(Image.FLIP_LEFT_RIGHT)
        img_flip.save(flip_full_file_name)

        # append a new image
        dict = {'image_pretty_name': new_idx, 'image_file_name': flip_core_file_name}
        rows_list.append(dict)

        # append a new split, use same flag for flipped image from original image
        is_training_image = full_img_content.iloc[0].is_training_image
        split_dict = {'image_pretty_name': new_idx, 'is_training_image': is_training_image}
        split_rows_list.append(split_dict)

        # append a new image class label
        label_dict = {'image_pretty_name': new_idx, 'class_id': class_id}
        label_rows_list.append(label_dict)

        # add a size row for the original and the flipped image, same height and width
        size_dict = {'idx': idx, 'width': width, 'height': height}
        size_rows_list.append(size_dict)

        size_dict = {'idx': new_idx, 'width': width, 'height': height}
        size_rows_list.append(size_dict)

        # append bounding box for flipped image

        x_abs = full_img_content.iloc[0].x_abs
        y_abs = full_img_content.iloc[0].y_abs
        bbox_width  = full_img_content.iloc[0].bbox_width
        bbox_height = full_img_content.iloc[0].bbox_height
        flipped_x_abs = width - bbox_width - x_abs

        bbox_dict = {'image_pretty_name': new_idx, 'x_abs': flipped_x_abs,
                    'y_abs': y_abs, 'bbox_width': bbox_width, 'bbox_height': bbox_height}
        bbox_rows_list.append(bbox_dict)

    print('Done looping through original images')

    images_df = images_df.append(rows_list)
    images_df[IMAGE_COLS].to_csv(IMAGE_FILE, sep=' ', index=False, header=None)
    bboxes_df = bboxes_df.append(bbox_rows_list)
    bboxes_df[BBOX_COLS].to_csv(BBOX_FILE, sep=' ', index=False, header=None)
    split_df = split_df.append(split_rows_list)
    split_df[SPLIT_COLS].to_csv(SPLIT_FILE, sep=' ', index=False, header=None)
    sizes_df = pd.DataFrame(size_rows_list)
    sizes_df[SIZE_COLS].to_csv(SIZE_FILE, sep=' ', index=False, header=None)
    image_class_labels_df = image_class_labels_df.append(label_rows_list)
    image_class_labels_df[LABEL_COLS].to_csv(LABEL_FILE, sep=' ', index=False, header=None)

    print('Done saving metadata in text files')

# %% [markdown]
# ## Re-train the model with the expanded dataset

# %%
# %%time

BBOX_FILE  = BASE_DIR + 'bounding_boxes_with_flip.txt'
IMAGE_FILE = BASE_DIR + 'images_with_flip.txt'
LABEL_FILE = BASE_DIR + 'image_class_labels_with_flip.txt'
SIZE_FILE  = BASE_DIR + 'sizes_with_flip.txt'
SPLIT_FILE = BASE_DIR + 'train_test_split_with_flip.txt'

# add a set of flipped images
flip_images()

# show the new full set of images for a species
show_species('017.Cardinal')

# create new sizes file
gen_image_size_file()

# re-create and re-deploy the RecordIO files with the updated set of images
train_df, val_df = gen_list_files()
# !python tools/im2rec.py --resize $RESIZE_SIZE --pack-label birds_ssd_sample $BASE_DIR/images/
sess.upload_data(path='birds_ssd_sample_train.rec', bucket=bucket, key_prefix=train_channel)
sess.upload_data(path='birds_ssd_sample_val.rec', bucket=bucket, key_prefix=validation_channel)

# account for the new number of training images
set_hyperparameters(100, '33,67')

# re-train
od_model.fit(inputs=data_channels, logs=True)

# check out the new accuracy
plot_object_detection_log(od_model, 'mAP tracking for job: ' + od_model._current_job_name)
# Out:
# Flipping images...
# Done looping through original images
# Done saving metadata in text files
# Species 017.Cardinal has 114 images.
# Generating a file containing image sizes...
# Image sizes:
#    idx  width  height
# 0    1    500     335
# 1    2    500     336
# 2    3    500     347
# 3    4    415     500
# 4    5    331     380
# CUB_200_2011/images_with_flip.txt
# num images total: 12085
# num train: 300
# num val: 294
# Creating .rec file from /home/ec2-user/SageMaker/object_detection_birds/birds_ssd_sample_val.lst in /home/ec2-user/SageMaker/object_detection_birds
# multiprocessing not available, fall back to single threaded encoding
# time: 0.00707697868347168  count: 0
# Creating .rec file from /home/ec2-user/SageMaker/object_detection_birds/birds_ssd_sample_train.lst in /home/ec2-user/SageMaker/object_detection_birds
# multiprocessing not available, fall back to single threaded encoding
# time: 0.006402730941772461  count: 0
# num classes: 5, num training images: 300
# 2020-10-08 16:18:14 Starting - Starting the training job...
# 2020-10-08 16:18:17 Starting - Launching requested ML instances......
# 2020-10-08 16:19:22 Starting - Preparing the instances for training......
# 2020-10-08 16:20:35 Downloading - Downloading input data
# 2020-10-08 16:20:35 Training - Downloading the training image........Docker entrypoint called with argument(s): train
# [10/08/2020 16:21:50 INFO 139843148203840] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/default-input.json: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'30', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'32', u'use_pretrained_model': u'0', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'', u'base_network': u'vgg-16', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'300'}
# [10/08/2020 16:21:50 INFO 139843148203840] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'learning_rate': u'0.001', u'epochs': u'100', u'nms_threshold': u'0.45', u'optimizer': u'sgd', u'base_network': u'resnet-50', u'image_shape': u'512', u'label_width': u'350', u'lr_scheduler_step': u'33,67', u'momentum': u'0.9', u'overlap_threshold': u'0.5', u'num_training_samples': u'300', u'mini_batch_size': u'16', u'weight_decay': u'0.0005', u'use_pretrained_model': u'1', u'num_classes': u'5', u'lr_scheduler_factor': u'0.1'}
# [10/08/2020 16:21:50 INFO 139843148203840] Final configuration: {u'label_width': u'350', u'early_stopping_min_epochs': u'10', u'epochs': u'100', u'overlap_threshold': u'0.5', u'lr_scheduler_factor': u'0.1', u'_num_kv_servers': u'auto', u'weight_decay': u'0.0005', u'mini_batch_size': u'16', u'use_pretrained_model': u'1', u'freeze_layer_pattern': u'', u'lr_scheduler_step': u'33,67', u'early_stopping': u'False', u'early_stopping_patience': u'5', u'momentum': u'0.9', u'num_training_samples': u'300', u'optimizer': u'sgd', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.0', u'learning_rate': u'0.001', u'kv_store': u'device', u'nms_threshold': u'0.45', u'num_classes': u'5', u'base_network': u'resnet-50', u'nms_topk': u'400', u'_kvstore': u'device', u'image_shape': u'512'}
# Process 1 is a worker.
# [10/08/2020 16:21:50 INFO 139843148203840] Using default worker.
# [10/08/2020 16:21:50 INFO 139843148203840] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [10/08/2020 16:21:50 INFO 139843148203840] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [10/08/2020 16:21:50 INFO 139843148203840] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [10/08/2020 16:21:50 INFO 139843148203840] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [10/08/2020 16:21:50 INFO 139843148203840] Checkpoint loading and saving are disabled.
# [10/08/2020 16:21:50 INFO 139843148203840] nvidia-smi took: 0.0502750873566 secs to identify 1 gpus
# [10/08/2020 16:21:50 INFO 139843148203840] Number of GPUs being used: 1
# [10/08/2020 16:21:50 WARNING 139843148203840] Training images are resized to image shape (3, 512, 512)
# [16:21:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, use 7 threads for decoding..
# [16:21:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, label padding width: 350
# [10/08/2020 16:21:52 WARNING 139843148203840] Validation images are resized to image shape (3, 512, 512)
# [16:21:52] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, use 7 threads for decoding..
# [16:21:52] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, label padding width: 350
# [10/08/2020 16:21:54 INFO 139843148203840] Number of GPUs being used: 1
# [10/08/2020 16:21:54 INFO 139843148203840] Using [gpu(0)] as training context.
# [10/08/2020 16:21:54 INFO 139843148203840] Number of GPUs being used: 1
# [10/08/2020 16:21:54 INFO 139843148203840] Create Store: device
# [10/08/2020 16:21:54 INFO 139843148203840] Using (gpu(0)) as training context.
# [10/08/2020 16:21:54 INFO 139843148203840] Start training from pretrained model 1.
# [16:21:54] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [16:21:54] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [10/08/2020 16:21:55 INFO 139843148203840] Loaded pretrained model parameters.
#
# 2020-10-08 16:21:48 Training - Training image download completed. Training in progress.[10/08/2020 16:22:06 INFO 139843148203840] Creating a new state instance.
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1602174126.303584, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1602174126.303477}
#
# [16:22:06] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_9.x.42.0/AL2012/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [10/08/2020 16:22:17 INFO 139843148203840] #quality_metric: host=algo-1, epoch=0, batch=19 train cross_entropy <loss>=(2.011658435973047)
# [10/08/2020 16:22:17 INFO 139843148203840] #quality_metric: host=algo-1, epoch=0, batch=19 train smooth_l1 <loss>=(0.6733638174633335)
# [10/08/2020 16:22:17 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:22:17 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:22:21 INFO 139843148203840] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(7.749143762434387e-05)
# [10/08/2020 16:22:21 INFO 139843148203840] Updating the best model with validation-mAP=7.749143762434387e-05
# [10/08/2020 16:22:21 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:22:21 INFO 139843148203840] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1602174141.374878, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 0}, "StartTime": 1602174126.303925}
#
# [10/08/2020 16:22:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=1, batch=19 train cross_entropy <loss>=(1.8233533523315253)
# [10/08/2020 16:22:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=1, batch=19 train smooth_l1 <loss>=(0.6536059428163664)
# [10/08/2020 16:22:26 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:22:26 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:22:30 INFO 139843148203840] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(0.00016322888221778406)
# [10/08/2020 16:22:30 INFO 139843148203840] Updating the best model with validation-mAP=0.00016322888221778406
# [10/08/2020 16:22:30 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:22:30 INFO 139843148203840] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1602174150.350342, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 1}, "StartTime": 1602174141.37511}
#
# [10/08/2020 16:22:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=2, batch=19 train cross_entropy <loss>=(1.794557411927656)
# [10/08/2020 16:22:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=2, batch=19 train smooth_l1 <loss>=(0.6611402188020377)
# [10/08/2020 16:22:35 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:22:35 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:22:39 INFO 139843148203840] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.00015878634262493402)
# [10/08/2020 16:22:39 INFO 139843148203840] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1602174159.334334, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 2}, "StartTime": 1602174150.350545}
#
# [10/08/2020 16:22:44 INFO 139843148203840] #quality_metric: host=algo-1, epoch=3, batch=18 train cross_entropy <loss>=(1.7641357585508126)
# [10/08/2020 16:22:44 INFO 139843148203840] #quality_metric: host=algo-1, epoch=3, batch=18 train smooth_l1 <loss>=(0.6265098571777343)
# [10/08/2020 16:22:44 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:22:44 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:22:47 INFO 139843148203840] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.0008323066292202704)
# [10/08/2020 16:22:47 INFO 139843148203840] Updating the best model with validation-mAP=0.0008323066292202704
# [10/08/2020 16:22:47 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:22:47 INFO 139843148203840] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1602174167.753203, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 3}, "StartTime": 1602174159.334519}
#
# [10/08/2020 16:22:54 INFO 139843148203840] #quality_metric: host=algo-1, epoch=4, batch=19 train cross_entropy <loss>=(1.736249693275103)
# [10/08/2020 16:22:54 INFO 139843148203840] #quality_metric: host=algo-1, epoch=4, batch=19 train smooth_l1 <loss>=(0.6378090330791958)
# [10/08/2020 16:22:54 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:22:54 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:22:57 INFO 139843148203840] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.006969511375037979)
# [10/08/2020 16:22:57 INFO 139843148203840] Updating the best model with validation-mAP=0.006969511375037979
# [10/08/2020 16:22:57 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:22:57 INFO 139843148203840] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1602174177.546585, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 4}, "StartTime": 1602174167.753431}
#
# [10/08/2020 16:23:03 INFO 139843148203840] #quality_metric: host=algo-1, epoch=5, batch=19 train cross_entropy <loss>=(1.7057775951030512)
# [10/08/2020 16:23:03 INFO 139843148203840] #quality_metric: host=algo-1, epoch=5, batch=19 train smooth_l1 <loss>=(0.6358601933098497)
# [10/08/2020 16:23:03 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:03 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:06 INFO 139843148203840] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.007403956225240255)
# [10/08/2020 16:23:06 INFO 139843148203840] Updating the best model with validation-mAP=0.007403956225240255
# [10/08/2020 16:23:06 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:06 INFO 139843148203840] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1602174186.630381, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 5}, "StartTime": 1602174177.554811}
#
# [10/08/2020 16:23:12 INFO 139843148203840] #quality_metric: host=algo-1, epoch=6, batch=19 train cross_entropy <loss>=(1.6644745682726951)
# [10/08/2020 16:23:12 INFO 139843148203840] #quality_metric: host=algo-1, epoch=6, batch=19 train smooth_l1 <loss>=(0.6291230841644478)
# [10/08/2020 16:23:12 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:12 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:15 INFO 139843148203840] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.013342309389216192)
# [10/08/2020 16:23:15 INFO 139843148203840] Updating the best model with validation-mAP=0.013342309389216192
# [10/08/2020 16:23:15 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:15 INFO 139843148203840] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1602174195.54631, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 6}, "StartTime": 1602174186.630637}
#
# [10/08/2020 16:23:20 INFO 139843148203840] #quality_metric: host=algo-1, epoch=7, batch=18 train cross_entropy <loss>=(1.6072740707752684)
# [10/08/2020 16:23:20 INFO 139843148203840] #quality_metric: host=algo-1, epoch=7, batch=18 train smooth_l1 <loss>=(0.6292889590591454)
# [10/08/2020 16:23:20 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:20 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:23 INFO 139843148203840] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.019505435518416124)
# [10/08/2020 16:23:23 INFO 139843148203840] Updating the best model with validation-mAP=0.019505435518416124
# [10/08/2020 16:23:23 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:23 INFO 139843148203840] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1602174203.7224, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 7}, "StartTime": 1602174195.546516}
#
# [10/08/2020 16:23:30 INFO 139843148203840] #quality_metric: host=algo-1, epoch=8, batch=19 train cross_entropy <loss>=(1.5222387714054104)
# [10/08/2020 16:23:30 INFO 139843148203840] #quality_metric: host=algo-1, epoch=8, batch=19 train smooth_l1 <loss>=(0.5951088599807286)
# [10/08/2020 16:23:30 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:30 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:34 INFO 139843148203840] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.029082672750972254)
# [10/08/2020 16:23:34 INFO 139843148203840] Updating the best model with validation-mAP=0.029082672750972254
# [10/08/2020 16:23:34 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:34 INFO 139843148203840] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1602174214.148511, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 8}, "StartTime": 1602174203.722678}
#
# [10/08/2020 16:23:39 INFO 139843148203840] #quality_metric: host=algo-1, epoch=9, batch=19 train cross_entropy <loss>=(1.4035502486860454)
# [10/08/2020 16:23:39 INFO 139843148203840] #quality_metric: host=algo-1, epoch=9, batch=19 train smooth_l1 <loss>=(0.6100011411875543)
# [10/08/2020 16:23:39 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:39 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.03417610229538876)
# [10/08/2020 16:23:43 INFO 139843148203840] Updating the best model with validation-mAP=0.03417610229538876
# [10/08/2020 16:23:43 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:43 INFO 139843148203840] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1602174223.167627, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 9}, "StartTime": 1602174214.148706}
#
# [10/08/2020 16:23:48 INFO 139843148203840] #quality_metric: host=algo-1, epoch=10, batch=19 train cross_entropy <loss>=(1.3171231410068946)
# [10/08/2020 16:23:48 INFO 139843148203840] #quality_metric: host=algo-1, epoch=10, batch=19 train smooth_l1 <loss>=(0.6089961877029934)
# [10/08/2020 16:23:48 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:48 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:23:52 INFO 139843148203840] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.05385741647195186)
# [10/08/2020 16:23:52 INFO 139843148203840] Updating the best model with validation-mAP=0.05385741647195186
# [10/08/2020 16:23:52 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:23:52 INFO 139843148203840] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1602174232.272755, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 10}, "StartTime": 1602174223.167836}
#
# [10/08/2020 16:23:57 INFO 139843148203840] #quality_metric: host=algo-1, epoch=11, batch=18 train cross_entropy <loss>=(1.243343509218228)
# [10/08/2020 16:23:57 INFO 139843148203840] #quality_metric: host=algo-1, epoch=11, batch=18 train smooth_l1 <loss>=(0.5880398280465627)
# [10/08/2020 16:23:57 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:23:57 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:00 INFO 139843148203840] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.07832227805237565)
# [10/08/2020 16:24:00 INFO 139843148203840] Updating the best model with validation-mAP=0.07832227805237565
# [10/08/2020 16:24:00 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:24:00 INFO 139843148203840] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1602174240.583617, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 11}, "StartTime": 1602174232.273115}
#
# [10/08/2020 16:24:06 INFO 139843148203840] #quality_metric: host=algo-1, epoch=12, batch=19 train cross_entropy <loss>=(1.166851957289471)
# [10/08/2020 16:24:06 INFO 139843148203840] #quality_metric: host=algo-1, epoch=12, batch=19 train smooth_l1 <loss>=(0.58664327865705)
# [10/08/2020 16:24:06 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:07 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:09 INFO 139843148203840] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.07394092541327905)
# [10/08/2020 16:24:09 INFO 139843148203840] #progress_metric: host=algo-1, completed 13 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1602174249.999745, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 12}, "StartTime": 1602174240.583912}
#
# [10/08/2020 16:24:15 INFO 139843148203840] #quality_metric: host=algo-1, epoch=13, batch=19 train cross_entropy <loss>=(1.1249076459047607)
# [10/08/2020 16:24:15 INFO 139843148203840] #quality_metric: host=algo-1, epoch=13, batch=19 train smooth_l1 <loss>=(0.590891057295765)
# [10/08/2020 16:24:15 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:15 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:18 INFO 139843148203840] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.09482638417860746)
# [10/08/2020 16:24:18 INFO 139843148203840] Updating the best model with validation-mAP=0.09482638417860746
# [10/08/2020 16:24:18 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:24:18 INFO 139843148203840] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1602174258.904012, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 13}, "StartTime": 1602174250.000019}
#
# [10/08/2020 16:24:24 INFO 139843148203840] #quality_metric: host=algo-1, epoch=14, batch=19 train cross_entropy <loss>=(1.081628089444552)
# [10/08/2020 16:24:24 INFO 139843148203840] #quality_metric: host=algo-1, epoch=14, batch=19 train smooth_l1 <loss>=(0.5826622914776842)
# [10/08/2020 16:24:24 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:24 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:27 INFO 139843148203840] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.08531158801128452)
# [10/08/2020 16:24:27 INFO 139843148203840] #progress_metric: host=algo-1, completed 15 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1602174267.630019, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 14}, "StartTime": 1602174258.904229}
#
# [10/08/2020 16:24:32 INFO 139843148203840] #quality_metric: host=algo-1, epoch=15, batch=18 train cross_entropy <loss>=(1.0375810244819625)
# [10/08/2020 16:24:32 INFO 139843148203840] #quality_metric: host=algo-1, epoch=15, batch=18 train smooth_l1 <loss>=(0.552084160241125)
# [10/08/2020 16:24:32 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:32 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.11165337952753393)
# [10/08/2020 16:24:35 INFO 139843148203840] Updating the best model with validation-mAP=0.11165337952753393
# [10/08/2020 16:24:35 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:24:35 INFO 139843148203840] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1602174275.544568, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 15}, "StartTime": 1602174267.634271}
#
# [10/08/2020 16:24:41 INFO 139843148203840] #quality_metric: host=algo-1, epoch=16, batch=19 train cross_entropy <loss>=(1.0117805778708364)
# [10/08/2020 16:24:41 INFO 139843148203840] #quality_metric: host=algo-1, epoch=16, batch=19 train smooth_l1 <loss>=(0.5453578564218018)
# [10/08/2020 16:24:41 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:42 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:45 INFO 139843148203840] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.14938797187790537)
# [10/08/2020 16:24:45 INFO 139843148203840] Updating the best model with validation-mAP=0.14938797187790537
# [10/08/2020 16:24:46 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:24:46 INFO 139843148203840] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1602174286.027196, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 16}, "StartTime": 1602174275.544997}
#
# [10/08/2020 16:24:51 INFO 139843148203840] #quality_metric: host=algo-1, epoch=17, batch=19 train cross_entropy <loss>=(0.9767957696682069)
# [10/08/2020 16:24:51 INFO 139843148203840] #quality_metric: host=algo-1, epoch=17, batch=19 train smooth_l1 <loss>=(0.5330359016976706)
# [10/08/2020 16:24:51 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:24:51 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:24:54 INFO 139843148203840] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.1314460968701379)
# [10/08/2020 16:24:54 INFO 139843148203840] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1602174294.632123, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 17}, "StartTime": 1602174286.027456}
#
# [10/08/2020 16:25:00 INFO 139843148203840] #quality_metric: host=algo-1, epoch=18, batch=19 train cross_entropy <loss>=(0.9677631162601256)
# [10/08/2020 16:25:00 INFO 139843148203840] #quality_metric: host=algo-1, epoch=18, batch=19 train smooth_l1 <loss>=(0.5179081609852484)
# [10/08/2020 16:25:00 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:00 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:03 INFO 139843148203840] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.14495534390075515)
# [10/08/2020 16:25:03 INFO 139843148203840] #progress_metric: host=algo-1, completed 19 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1602174303.634743, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 18}, "StartTime": 1602174294.632328}
#
# [10/08/2020 16:25:08 INFO 139843148203840] #quality_metric: host=algo-1, epoch=19, batch=18 train cross_entropy <loss>=(0.9529116313967599)
# [10/08/2020 16:25:08 INFO 139843148203840] #quality_metric: host=algo-1, epoch=19, batch=18 train smooth_l1 <loss>=(0.5256189920768914)
# [10/08/2020 16:25:08 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:08 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:11 INFO 139843148203840] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.14568076479692885)
# [10/08/2020 16:25:11 INFO 139843148203840] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 20, "sum": 20.0, "min": 20}}, "EndTime": 1602174311.691717, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 19}, "StartTime": 1602174303.635002}
#
# [10/08/2020 16:25:17 INFO 139843148203840] #quality_metric: host=algo-1, epoch=20, batch=19 train cross_entropy <loss>=(0.9436096379322372)
# [10/08/2020 16:25:17 INFO 139843148203840] #quality_metric: host=algo-1, epoch=20, batch=19 train smooth_l1 <loss>=(0.5055000474300291)
# [10/08/2020 16:25:17 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:18 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:20 INFO 139843148203840] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.16327097160652257)
# [10/08/2020 16:25:20 INFO 139843148203840] Updating the best model with validation-mAP=0.16327097160652257
# [10/08/2020 16:25:21 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:25:21 INFO 139843148203840] #progress_metric: host=algo-1, completed 21 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 21, "sum": 21.0, "min": 21}}, "EndTime": 1602174321.074005, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 20}, "StartTime": 1602174311.691867}
#
# [10/08/2020 16:25:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=21, batch=19 train cross_entropy <loss>=(0.9341069448696853)
# [10/08/2020 16:25:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=21, batch=19 train smooth_l1 <loss>=(0.5033790849116015)
# [10/08/2020 16:25:26 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:26 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:29 INFO 139843148203840] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.14306039490269)
# [10/08/2020 16:25:29 INFO 139843148203840] #progress_metric: host=algo-1, completed 22 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 22, "sum": 22.0, "min": 22}}, "EndTime": 1602174329.852101, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 21}, "StartTime": 1602174321.074227}
#
# [10/08/2020 16:25:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=22, batch=19 train cross_entropy <loss>=(0.936435479966421)
# [10/08/2020 16:25:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=22, batch=19 train smooth_l1 <loss>=(0.4955420248092167)
# [10/08/2020 16:25:35 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:35 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:38 INFO 139843148203840] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(0.1871689344720477)
# [10/08/2020 16:25:38 INFO 139843148203840] Updating the best model with validation-mAP=0.1871689344720477
# [10/08/2020 16:25:38 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:25:38 INFO 139843148203840] #progress_metric: host=algo-1, completed 23 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 23, "sum": 23.0, "min": 23}}, "EndTime": 1602174338.513415, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 22}, "StartTime": 1602174329.86038}
#
# [10/08/2020 16:25:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=23, batch=18 train cross_entropy <loss>=(0.916772798605901)
# [10/08/2020 16:25:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=23, batch=18 train smooth_l1 <loss>=(0.4824104508178966)
# [10/08/2020 16:25:43 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:43 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:46 INFO 139843148203840] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.1886603595400797)
# [10/08/2020 16:25:46 INFO 139843148203840] Updating the best model with validation-mAP=0.1886603595400797
# [10/08/2020 16:25:46 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:25:46 INFO 139843148203840] #progress_metric: host=algo-1, completed 24 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 24, "sum": 24.0, "min": 24}}, "EndTime": 1602174346.433174, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 23}, "StartTime": 1602174338.513628}
#
# [10/08/2020 16:25:52 INFO 139843148203840] #quality_metric: host=algo-1, epoch=24, batch=19 train cross_entropy <loss>=(0.9194428418384561)
# [10/08/2020 16:25:52 INFO 139843148203840] #quality_metric: host=algo-1, epoch=24, batch=19 train smooth_l1 <loss>=(0.48872045438075007)
# [10/08/2020 16:25:52 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:25:52 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:25:56 INFO 139843148203840] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.20140479958424665)
# [10/08/2020 16:25:56 INFO 139843148203840] Updating the best model with validation-mAP=0.20140479958424665
# [10/08/2020 16:25:56 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:25:56 INFO 139843148203840] #progress_metric: host=algo-1, completed 25 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 25, "sum": 25.0, "min": 25}}, "EndTime": 1602174356.661331, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 24}, "StartTime": 1602174346.433439}
#
# [10/08/2020 16:26:02 INFO 139843148203840] #quality_metric: host=algo-1, epoch=25, batch=19 train cross_entropy <loss>=(0.9013758016816268)
# [10/08/2020 16:26:02 INFO 139843148203840] #quality_metric: host=algo-1, epoch=25, batch=19 train smooth_l1 <loss>=(0.4687693909268571)
# [10/08/2020 16:26:02 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:26:02 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:26:05 INFO 139843148203840] #quality_metric: host=algo-1, epoch=25, validation mAP <score>=(0.21049596458380665)
# [10/08/2020 16:26:05 INFO 139843148203840] Updating the best model with validation-mAP=0.21049596458380665
# [10/08/2020 16:26:05 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:26:05 INFO 139843148203840] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 26, "sum": 26.0, "min": 26}}, "EndTime": 1602174365.350029, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 25}, "StartTime": 1602174356.661524}
#
# ...
#
# [10/08/2020 16:35:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=90, batch=19 train cross_entropy <loss>=(0.6381041643845003)
# [10/08/2020 16:35:26 INFO 139843148203840] #quality_metric: host=algo-1, epoch=90, batch=19 train smooth_l1 <loss>=(0.2450665640878965)
# [10/08/2020 16:35:26 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:35:26 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:35:29 INFO 139843148203840] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.9158989937183973)
# [10/08/2020 16:35:29 INFO 139843148203840] #progress_metric: host=algo-1, completed 91 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 91, "sum": 91.0, "min": 91}}, "EndTime": 1602174929.640327, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 90}, "StartTime": 1602174921.177693}
#
# [10/08/2020 16:35:34 INFO 139843148203840] #quality_metric: host=algo-1, epoch=91, batch=18 train cross_entropy <loss>=(0.6492102273490176)
# [10/08/2020 16:35:34 INFO 139843148203840] #quality_metric: host=algo-1, epoch=91, batch=18 train smooth_l1 <loss>=(0.24945377408354955)
# [10/08/2020 16:35:34 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:35:34 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:35:37 INFO 139843148203840] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.9020778724936467)
# [10/08/2020 16:35:37 INFO 139843148203840] #progress_metric: host=algo-1, completed 92 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 92, "sum": 92.0, "min": 92}}, "EndTime": 1602174937.279051, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 91}, "StartTime": 1602174929.640616}
#
# [10/08/2020 16:35:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=92, batch=19 train cross_entropy <loss>=(0.6193418774216402)
# [10/08/2020 16:35:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=92, batch=19 train smooth_l1 <loss>=(0.23858837430914673)
# [10/08/2020 16:35:43 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:35:43 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:35:46 INFO 139843148203840] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.9013107321569596)
# [10/08/2020 16:35:46 INFO 139843148203840] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 93, "sum": 93.0, "min": 93}}, "EndTime": 1602174946.183451, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 92}, "StartTime": 1602174937.279237}
#
# [10/08/2020 16:35:51 INFO 139843148203840] #quality_metric: host=algo-1, epoch=93, batch=19 train cross_entropy <loss>=(0.6112501813077379)
# [10/08/2020 16:35:51 INFO 139843148203840] #quality_metric: host=algo-1, epoch=93, batch=19 train smooth_l1 <loss>=(0.23812822455190608)
# [10/08/2020 16:35:51 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:35:51 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:35:54 INFO 139843148203840] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.9515711293942524)
# [10/08/2020 16:35:54 INFO 139843148203840] Updating the best model with validation-mAP=0.9515711293942524
# [10/08/2020 16:35:54 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:35:54 INFO 139843148203840] #progress_metric: host=algo-1, completed 94 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 94, "sum": 94.0, "min": 94}}, "EndTime": 1602174954.6385, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 93}, "StartTime": 1602174946.183704}
#
# [10/08/2020 16:35:59 INFO 139843148203840] #quality_metric: host=algo-1, epoch=94, batch=19 train cross_entropy <loss>=(0.6125911491367565)
# [10/08/2020 16:35:59 INFO 139843148203840] #quality_metric: host=algo-1, epoch=94, batch=19 train smooth_l1 <loss>=(0.2369933442781039)
# [10/08/2020 16:35:59 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:00 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:02 INFO 139843148203840] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.9475108179607193)
# [10/08/2020 16:36:02 INFO 139843148203840] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 95, "sum": 95.0, "min": 95}}, "EndTime": 1602174962.74492, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 94}, "StartTime": 1602174954.638696}
#
# [10/08/2020 16:36:07 INFO 139843148203840] #quality_metric: host=algo-1, epoch=95, batch=18 train cross_entropy <loss>=(0.5827003152304392)
# [10/08/2020 16:36:07 INFO 139843148203840] #quality_metric: host=algo-1, epoch=95, batch=18 train smooth_l1 <loss>=(0.22262314284778661)
# [10/08/2020 16:36:07 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:07 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:09 INFO 139843148203840] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.96021427456584)
# [10/08/2020 16:36:09 INFO 139843148203840] Updating the best model with validation-mAP=0.96021427456584
# [10/08/2020 16:36:10 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:36:10 INFO 139843148203840] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1602174970.130441, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 95}, "StartTime": 1602174962.746119}
#
# [10/08/2020 16:36:16 INFO 139843148203840] #quality_metric: host=algo-1, epoch=96, batch=19 train cross_entropy <loss>=(0.6019896848442204)
# [10/08/2020 16:36:16 INFO 139843148203840] #quality_metric: host=algo-1, epoch=96, batch=19 train smooth_l1 <loss>=(0.22886211358896763)
# [10/08/2020 16:36:16 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:16 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:19 INFO 139843148203840] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.9394703187883774)
# [10/08/2020 16:36:19 INFO 139843148203840] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1602174979.68169, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 96}, "StartTime": 1602174970.130659}
#
# [10/08/2020 16:36:25 INFO 139843148203840] #quality_metric: host=algo-1, epoch=97, batch=19 train cross_entropy <loss>=(0.6175729006775155)
# [10/08/2020 16:36:25 INFO 139843148203840] #quality_metric: host=algo-1, epoch=97, batch=19 train smooth_l1 <loss>=(0.23902807945062307)
# [10/08/2020 16:36:25 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:25 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:27 INFO 139843148203840] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.9317711271898637)
# [10/08/2020 16:36:27 INFO 139843148203840] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1602174987.818907, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 97}, "StartTime": 1602174979.681912}
#
# [10/08/2020 16:36:33 INFO 139843148203840] #quality_metric: host=algo-1, epoch=98, batch=19 train cross_entropy <loss>=(0.5956142897904655)
# [10/08/2020 16:36:33 INFO 139843148203840] #quality_metric: host=algo-1, epoch=98, batch=19 train smooth_l1 <loss>=(0.23504113986331016)
# [10/08/2020 16:36:33 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:33 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:35 INFO 139843148203840] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.889079945078781)
# [10/08/2020 16:36:35 INFO 139843148203840] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1602174995.821294, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 98}, "StartTime": 1602174987.827186}
#
# [10/08/2020 16:36:40 INFO 139843148203840] #quality_metric: host=algo-1, epoch=99, batch=18 train cross_entropy <loss>=(0.6028893513094352)
# [10/08/2020 16:36:40 INFO 139843148203840] #quality_metric: host=algo-1, epoch=99, batch=18 train smooth_l1 <loss>=(0.233012982759401)
# [10/08/2020 16:36:40 INFO 139843148203840] Round of batches complete
# [10/08/2020 16:36:40 INFO 139843148203840] Updated the metrics
# [10/08/2020 16:36:43 INFO 139843148203840] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.9512029855695857)
# [10/08/2020 16:36:43 INFO 139843148203840] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Records Seen": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Max Records Seen Between Resets": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1602175003.3842, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/Object Detection", "epoch": 99}, "StartTime": 1602174995.821485}
#
# [10/08/2020 16:36:43 WARNING 139843148203840] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [10/08/2020 16:36:43 INFO 139843148203840] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [10/08/2020 16:36:43 INFO 139843148203840] Test data is not provided.
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "totaltime": {"count": 1, "max": 893858.0751419067, "sum": 893858.0751419067, "min": 893858.0751419067}, "setuptime": {"count": 1, "max": 9.276151657104492, "sum": 9.276151657104492, "min": 9.276151657104492}}, "EndTime": 1602175004.664562, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/Object Detection"}, "StartTime": 1602174110.912287}
#
#
# 2020-10-08 16:37:25 Uploading - Uploading generated training model
# 2020-10-08 16:37:25 Completed - Training job completed
# Training seconds: 1026
# Billable seconds: 1026
# mAP tracking for job: object-detection-2020-10-08-16-18-13-838
# Maximum mAP: 0.960214
# CPU times: user 1min 6s, sys: 914 ms, total: 1min 7s
# Wall time: 20min 36s

# %% [markdown]
# ## Re-deploy and test

# %%
# host the updated model
object_detector = od_model.deploy(initial_instance_count = 1, instance_type = 'ml.m4.xlarge')

# test the new model
test_model()
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!068.Ruby_throated_Hummingbird,0.8676913976669312
# Number of detections: 1
# 073.Blue_Jay,0.6039915680885315
# Number of detections: 1
# 047.American_Goldfinch,0.9825477004051208
# 047.American_Goldfinch,0.8968935608863831
# Number of detections: 2
# 036.Northern_Flicker,0.9229751229286194
# Number of detections: 1
# 017.Cardinal,0.7365002036094666
# Number of detections: 1

# %% [markdown]
# ## Final cleanup
# Here we delete the SageMaker endpoint, as we will no longer be performing any inferences.  This is an important step, as your account is billed for the amount of time an endpoint is running, even when it is idle.

# %%
# delete the new endpoint
sagemaker.Session().delete_endpoint(object_detector.endpoint)
